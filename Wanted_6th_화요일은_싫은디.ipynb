# %% [markdown]
# <a href="https://colab.research.google.com/github/seulgiKim95/WordCloud/blob/Daehyeon/Wanted_6th_%ED%99%94%EC%9A%94%EC%9D%BC%EC%9D%80_%EC%8B%AB%EC%9D%80%EB%94%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![8m4dojqn3vio39trwpon8r2d3m4h.png](data:image/png;base64,...)

# %% [markdown]
# # 가보자고~~

# %% [markdown]
# 이해가 안 가거나 추가 했으면 하는 내용, 설명이 부족한 부분들을 체크해주세요. 추가하겠습니다.

# %%
# 이 페이지를 열었을 때 마다 실행해야 됩니다. 
# 코랩은 로컬환경(내 pc에 저장소)에 설치한 라이브러리를 저장하지 않기 때문입니다.
# 실행 후 아래 코드는 주석 처리 해주세요. 주석은 필요부분을 블록처리(드래그나 [Shift]키로 지정)
# 한 영역에 [Ctrl] + [/] 키를 누르면 주석 처리가 됩니다. (한 줄 단위도 됩니다.)
# !pip install beautifulsoup4 #뷰티플수프 라이브러리
# !pip install selenium #셀리니움 라이브러리
# !apt-get update #크롬브라우저는 계속 업데이트가 되기 때문에 자동으로 업데이트를 할 수 있게 해줍니다.
# !apt install chromium-chromedriver #셀레니움 이용시 크롬 드라이버가 꼭 필요합니다.
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.3.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.11)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2022.6.15)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (37.0.4)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (22.0.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (4.1.1)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (101.0.4951.64-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 71 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
## 필요한 라이브러리 import

# -*- coding: UTF-8 -*-
import time #시간지연을 해주기 위함입니다.
import pandas as pd #pandas가 추가 되었습니다. 데이터프레임 생성시 필요
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import json # 아래 필요 이유 서술

# %%
options = webdriver.ChromeOptions() #기본 설정이라고 생각하시면 됩니다. 바로 실행 ㄱㄱ
options.add_argument('--headless')        ## Head-less 설정
options.add_argument('--no-sandbox')    # 이 설정이 있기 때문에 크롬창이 뜨지 않아요.
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome('chromedriver', options=options)

# %%
base_url = "https://www.wanted.co.kr/" #저희는 '원티드' 사이트를 조사하기로 했죠? 
                                       # 만약 다른 사이트를 할 경우 여기 다른 사이트주소를 입력합니다.
keyword = "머신러닝 엔지니어" # 저희가 찾을 직무를 입력합니다
                          # 데이터 엔지니어, 데이터 분석가, 데이터 사이언티스트, 머신러닝 엔지니어, 데이터 플랫폼 개발자
                          # DBA, 임베디드, IoT, 마켓팅 팀의 데이터 전문가, 정보보안, 백엔드, 풀스택 개발자
                          # 띄어쓰기(공백) 포함입니다.

# %%
## 해당 url로 이동
driver = webdriver.Chrome('chromedriver', options=options)
driver.get(base_url) #base_url변수에는 위에 '원티드'사이트 URL이 들어있습니다.

## 사이트에서 검색어 입력 부분(검색어 창)을 찾아 xpath로 넣어 찾아준다. 사이트에서 돋보기 부분 해당
driver.find_element('xpath','//*[@id="__next"]/div[1]/div/nav/aside/ul/li[1]/button').send_keys(Keys.ENTER)

#search_job = driver.find_element('xpath','//*[@id="__next"]/div[1]/div[2]/div/form/input') # 돋보기를 누른 뒤 검색창에 해당
search_job = driver.find_element('xpath','//*[@id="__next"]/div[1]/div[2]/div/form/input')

## 찾은 검색어 창에 검색어를 입력하고 enter를 친다.
search_job.send_keys(keyword+Keys.ENTER) #keyword는 '직무'가 담겨져 있습니다. 
                                         #현재 keyword에는 '데이터 분석가'가 들어가 있고
                                         #Keys.ENTER로 검색합니다.
                                         #검색창에 데이터 전문가 라고 치고 엔터키 누른 것과 동일

## 페이지가 로딩 되는 동안 기다려준다.(여기서는 5초) #안해주면 사이트를 읽어 올 수가 없습니다.
time.sleep(5) #단위는 초                                       #꼭 5초가 아니어도 되지만 여유 있게 시간을 줍시다.

# 페이지 스크롤 다 내리기
# 원티트 홈페이지에서 우리가 원하는 채용공고를 확인하려면 페이지 스크롤을 다 내려주어야 합니다.
# 웹페이지가 스크롤을 하기 전에는 20개씩 결과를 보여줍니다. 모두 보기 위해서 페이지 스크롤을 내려줄게요.
# 페이지 스크롤 부분 코드를 꼭 다 이해하실 필요는 없습니다. 이 구조 자체가 스크롤을 내려주기 위해 필요한 구조라고 생각해주세요.
prev_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 스크롤을 화면 가장 아래로 내린다
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    
    # 페이지 로딩 대기
    time.sleep(2)

    # 현재 문서 높이를 가져와서 저장
    curr_height = driver.execute_script("return document.body.scrollHeight")

    if(curr_height == prev_height):
        break
    else:
        prev_height = driver.execute_script("return document.body.scrollHeight")

## 페이지 소스를 html 변수에 저장하고 driver를 닫아준다.
html = driver.page_source #여기에는 우리가 엔터를 쳐서 들어간 페이지의 모든 html정보가 들어갑니다.
driver.quit() #파일 입출력 때 f.close()와 비슷하다고 생각해주세요.

# %%
# 궁금하시면 주석을 지우고 확인해 보세요.
#print(type(html))
#print(html)

# %%
## 페이지 소스를 beautifulsoup 객체로 만들어준다.
page_soup = BeautifulSoup(html, 'html.parser') #html.parser는 'html을 분석한다'고 생각하시면 됩니다.
                                               #여기서부터는 BeautifulSoup가 쓰이기 시작합니다.

# %%
## 우리가 필요한 데이터가 있는 곳의 태그와 class 이름을 찾아서 모두 찾아준다.
#'데이터 분석가를 검색했을 때 각 회사 정보가 뜹니다. 자세한 정보를 보려면 각 회사의 이미지(링크)를
#클릭 했어야 했습니다. 따라서 우리가 찾을 html태그는 링크 태그인 'a' 입니다.
#클래스 이름을 찾으려고 보니 class는 없고 'class aria-label=position link' 이라고 있네요.
#find_all()함수의 요소에 우리가 찾는 태그를 첫번째 인자값으로 넣고,
#두번째 인자값에는 딕셔너리 구조로 넣어주세요 '=' 이 딕셔너리 ':'에 해당됩니다. class는 지우고 'aria-label만 입력  
keyword_result = page_soup.find_all('a',{'aria-label':'position link'}) #fin_all() 만족하는 것 다 찾음 find는 하나만

#keyword_result #궁금하시면 주석 지우고 실행해보세요.

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
keyword_list = []
for i in keyword_result:
  if keyword in i.text: #.text는 태그안에 있는 텍스트만 출력해줍니다.
    ## 찾은 태그가 포함된 소스에서 href 내용만 가져와서 list에 추가해준다.
    keyword_list.append(i['href'])

# %%
print(keyword_list) #하나 하나가 우리가 찾아야 하는 회사입니다.
# Out:
# ['/wd/18238', '/wd/77382', '/wd/104274', '/wd/23634', '/wd/44698', '/wd/107329', '/wd/112362', '/wd/121022', '/wd/104227', '/wd/101934', '/wd/35398', '/wd/49706', '/wd/94542', '/wd/119154', '/wd/112204', '/wd/111503', '/wd/111480', '/wd/111502', '/wd/42992', '/wd/85675', '/wd/100694', '/wd/98939', '/wd/78801', '/wd/106218', '/wd/110592', '/wd/110902', '/wd/72264', '/wd/115645', '/wd/115642', '/wd/106997', '/wd/43741', '/wd/34990', '/wd/84251', '/wd/51080', '/wd/121972', '/wd/111749']

# %%
len(keyword_list) # 길이를 구하면 몇 건인지 알 수 있습니다.
#print(keyword_list[0]) #이것도 궁금하시면 주석 지우고 해보세요
# Out:
# 36

# %%
info_list = ['주요업무', '자격요건', '우대사항', '혜택 및 복지', '기술스택 ・ 툴'] # 원티드는 이 키워드로 형식이 맞추어서 있습니다. 운이 좋네요^^
print(info_list)
# Out:
# ['주요업무', '자격요건', '우대사항', '혜택 및 복지', '기술스택 ・ 툴']

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %%
# 비어있는 데이터 프레임을 생성합니다. 이 데이터 프레임에 우리가 찾는 정보를 저장하겠습니다.
columns=['회사이름','주요업무', '자격요건', '우대사항', '혜택 및 복지', '기술스택 ・ 툴', '지역']
df = pd.DataFrame(columns=columns)
df
# Out:
# Empty DataFrame
# Columns: [회사이름, 주요업무, 자격요건, 우대사항, 혜택 및 복지, 기술스택 ・ 툴, 지역]
# Index: []

# %%
# for문을 사용해 회사 별 링크로 이동 한 뒤
# 다시 for문을 만나 info_list의 정보를 찾은 뒤
# 회사 이름과 위치를 찾은 다음 for문을 나간다.

for i in range(len(keyword_list)):
  try: # 회사 지역이 없는 경우가 발생, try except문 추가
    info_tag_line = []
    driver = webdriver.Chrome('chromedriver', options=options)
    #driver.get('https://www.wanted.co.kr/wd/121695')
    driver.get('https://www.wanted.co.kr'+keyword_list[i]) #keyword_list증가시키며 링크 이동
    # time.sleep(1) #관계없어보임
    h = driver.page_source
    driver.quit()

    com_html = BeautifulSoup(h,'html.parser')

    company_name = com_html.find('h5') #회사이름

    # 보통 우리가 지금까지 필요한 정보를 찾던 방식은 HTML태그를 찾거나 태그의 클래스 이름 등을 찾아서 필요한 정보를 찾았습니다.
    # 그러나, Javascript태그로 들어가 있는 정보가 있더군요. Javascript는 java랑 다릅니다. HTML, CSS, Javasript이 세가지로 웹페이지를 구상합니다.
    # 웹상에서는 일반 HTML태그안에 있는데 HTML정보를 불러오고 보니 Javasript태그가 보이더군요.

    company_loc = com_html.find('script',{'type':'application/ld+json'}) #회사 주소 불러오기 #import json 을 한 이유 # 한 줄씩 처리되기에 변수 이름이 같아도 상관없습니다. 
    company_loc = dict(json.loads(company_loc.text))['jobLocation']['address']['streetAddress'] 
  except:
    continue

  for j in info_list:
        info_tag = com_html.find('h6', string = j) #'주요업무', '자격요건', '우대사항', '혜택 및 복지', '기술스택 ・ 툴'
        if info_tag != None: #주요업무, 자격요건, 우대사항, 혜택 및 복지는 다 있지만 기술스택 툴은 없는 기업도 있습니다.
          if j == '기술스택 ・ 툴':  # info_tag가 None이 아니라면 즉 어떤 값이 있다면 if문 아래 두번쨰 if문을 수행 합니다. 
            info_tag_line.append(list(map(lambda x:x.text,info_tag.next_element.next_element.findChild().findChildren())))  #기술스택 ・ 툴을 적어 놓지 않는 기업도 있기에 구별합니다.
          else:  
            info_tag_line.append(info_tag.nextSibling.text)   
        else:
          info_tag_line.append(0) #info_tag가 None 즉 값이 없다면 0을 채워줍니다.
     
  df = df.append(pd.Series([company_name, info_tag_line[0], info_tag_line[1], info_tag_line[2], info_tag_line[3], info_tag_line[4], company_loc],index=columns),ignore_index=True) # 데이터 프레임에 차곡차곡 저장
        #df = df.append(pd.Series([company_name]+info_tag_line+[company_loc],index=columns),ignore_index=True)
  i += 1  # 첫번째 for문의 i값을 증가시켜 사이트 주소를 바꿔 다시 찾습니다. 첫번째 for문이 끝날때까지 반복합니다. 대략 최장6분에서 최소 2분정도 걸립니다. 71건이 5분 40초, 31건이 2분 4초 걸림

# df.to_csv("wanted_IoT.csv", sep=',', encoding = "UTF-8") # CSV or Excel로 저장시 이름 바꿔주세요. #마지막으로 

#회사 이름에 들어가 있는 html Tag 제거 # 이대로 출력한다면 회사 이름에는 태그가 그대로 같이 나옵니다. 태그를 제거하고 택스트만 추출할게요.
def name(x):
  if x:
    return x.text

df['회사이름'] = df['회사이름'].apply(name)

df.to_csv("머신러닝엔지니어.csv", sep=',', encoding = "UTF-8") # CSV or Excel로 저장시 이름 바꿔주세요. # 마지막으로 저장합니다. 찾는 직무가 달라질 때마다 꼭! 꼭! 이름을 바꿔줍니다.

# %%
df # 만든 데이터 프레임 확인할게요. 잘 만들어 졌습니다.

# 찾아야 하는 결과가 많을 수록 간혹 회사이름, 주요업무, 자격요건, 우대사항, 혜택 및 복지가 0으로 나올때가 있습니다. 런타임오류 인듯 합니다.
# 12가지 직무 다 돌려보고 오류 수정에 대한 이야기를 해야 할거 같아요. # 기술스택 ・ 툴은 0이 나올 수 있습니다. 그건 오류가 아니에요.
# Out:
#                       회사이름                                               주요업무  \
# 0         스캐터랩(Scatterlab)  1) 데이터 전처리 및 모델 학습    Keywords: Python, Tensor...
# 1         스캐터랩(Scatterlab)  1) 데이터 전처리 및 모델 학습    Keywords: Python, Tensor...
# 2                       룩코  - 의류 이미지 속성 추출/탐지 및 이미지 검색 모델 학습- 딥 러닝 알고리즘 개발...
# 3                     액션파워  연구했던 분야를 고려하여 액션파워에서의 연구 주제를 정합니다.[음성, 음향 관련 연...
# 4                에이블리코퍼레이션  • 개인화 추천, 랭킹 시스템 개발을 개발해요.• CTR, 재고 등 시계열 예측 시...
# 5                      몰로코  • 머신러닝 팀 구성 및 리딩• 다양한 비즈니스 어플리케이션을 위한 확장된 머신러닝...
# 6                     메디웨일  • 안저이미지로 안과질환을 판독하는 Robust 한 AI모델개발• 다양한 Sourc...
# 7                줌인터넷(ZUM)  [이런 업무를 담당합니다]- 줌인터넷의 검색 포털인 줌닷컴과 금융 관련 서비스인 줌...
# 8          에잇퍼센트(8PERCENT)  • 신용평가 모형을 개발합니다.• Fraud Detection 모형을 개발합니다.•...
# 9             버즈빌(buzzvil)  버즈빌의 머신러닝 리드는 노출형 광고팀에 소속되어 광고주들에게 최상의 광고 성과를 ...
# 10  마인드로직 (Mindlogic Inc.)  Python, Machinelearning 자연어 처리 및 챗봇용 신경망 구현 (의...
# 11                      푸시               • 뉴스 기사 및 주식 데이터 분석• 뉴스 기사 추천시스템 개발"
# 12          코딧(CODITCorp.)  • 법률 및 규제 번역 NMT 모델을 개발합니다.• 기업 및 산업별 추천 시스템을 ...
# 13                    None                                                  0
# 14                     디쉐어  뛰어난 동료들과 함께 다양한 문제들에 대해 적극적으로 해결해 나가실 분을 찾습니다....
# 15                  하렉스인포텍  • 디지털 나(Digital Me) 알고리듬 개발 • 사용자의 상태를 파악하여 적절...
# 16                  하렉스인포텍                                     • AI 공유 플랫폼 개발
# 17                  하렉스인포텍  • 자연어처리 딥러닝 기반 추천엔진 솔루션 개발• 다국어 구매 기록을 활용한 초개인...
# 18                    플라스크  • 3D Human Pose Estimation 관련 연구 및 개발• 머신러닝 모델...
# 19           아우름플래닛(LINER)  - 다양한 모달리티의 컨텐츠에서 피쳐를 추출하고 이를 기반으로 추천 시스템 발전- ...
# 20              핏펫(Fitpet)  구매 데이터와 동물병원 영수증 진료내역, 구강검사키트 검진 데이터와 사용자가 등록한...
# 21                     클라썸  - 서비스 내 다양한 데이터를 활용한 Machine Learning 엔진 개발 및 ...
# 22       아이지에이웍스(IGAWorks)  • 실제 유저들의 행동 모델과 제품 분석은 위한 머신러닝, 데이터 마이닝 알고리즘 ...
# 23                   데일리펀딩                  • 머신러닝 기반의 비정형 데이터 분석 모델을 구축 합니다.
# 24                    하이로컬  - Machine learning lead    - Why you’ll like w...
# 25            의식주컴퍼니(런드리고)  • 의식주컴퍼니에 있는 수백만 장의 의류 데이터로부터 카테고리, 넥라인, 소재, 질...
# 26         이스트소프트(ESTsoft)  [이런 업무를 담당합니다]- Vision 머신러닝/딥러닝 알고리즘 개발 및 서비스화...
# 27                    빅픽처팀         • 한국어 대화 모델 연구 및 개발• 한국어 자연어 모델링• 문제 생성 작업
# 28                    빅픽처팀  • Acoustic Model 연구 및 개발• Neural Vocoder 연구 및 ...
# 29            넥슨코리아(NEXON)  • 머신러닝 모델의 실제 프로덕션 환경 적용• 도메인 문제 해결을 위한 모델 개발•...
# 30            넥슨코리아(NEXON)  • 머신러닝 모델의 실제 프로덕션 환경 적용• 도메인 문제 해결을 위한 모델 개발•...
# 31                   뱅크샐러드  • 뱅크샐러드 서비스에 적용되는 ML 모델을 배포하고, 운영하고, 개선해 나갑니다....
# 32                 코리아폴리스쿨  • 자연어처리 (NLP) 부문 인공지능 서비스 연구 및 개발• 질의응답, 기계독해,...
# 33               엘비스(LVIS)  • 최신의 머신 러닝 알고리즘을 이용한 인공 지능 기반의 의료 진단 시스템 디자인•...
# 34                   오케스트로  • 인공지능 기반 클라우드 최적화 솔루션(AIOps) SYMPHONY A.I. 개발...
# 35                 포항공과대학교  • 중소기업 트레이닝 프로그램 참여 지원, 기술 지원, 새로운 공정 도입 및 트레이...
#
#                                                  자격요건  \
# 0   • Python 기반 개발에 능숙하신 분• Pytorch, Tensorflow 를 ...
# 1   • 관련 업무에 5년 이상 경험이 있으신 분• Python 기반 개발에 능숙하신 분...
# 2   - Python 언어로 원하는 것을 개발/구현 가능하신 분- DL Framework...
# 3   • 필요 역량- 자동화를 좋아하셔서, 귀찮고 반복적인 것들은 컴퓨터에게 시키고, 그...
# 4   • 머신러닝 관련 업무 경력이 5년 이상이거나, 그에 준하는 역량을 갖고 계신 분을...
# 5   • 컴퓨터공학 또는 관련 분야 석사/박사 학위• 머신러닝, 딥러닝 관련 분야 6년 ...
# 6   • 머신러닝/의학논문 작성 경험• 의료 인공지능 개발 프로젝트 개발경험• 의학통계분...
# 7   [이런 역량을 갖춘 분을 찾습니다]- 머신러닝을 활용하여 서비스의 문제를 해결한 경...
# 8   • 관련 업무에 3년 이상 경험이 있으신 분• Python과 머신러닝 프레임워크를 ...
# 9   • 팀 리드 경험이 있습니다.• 딥 러닝 및 전통적인 머신러닝 주제들에 대해 잘 이...
# 10  •\tPytorch 프레임워크 사용 경험•\t자연어처리, 챗봇 관련 논문들의 구현 ...
# 11  • (필수) 2년 이상의 해당 분야 개발 경험 또는 그에 준하는 역량 보유자• Py...
# 12  • ML 모델 개발 및 관련 경력 3년 이상인 분을 찾습니다.• 머신러닝 파이프라인...
# 13                                                  0
# 14  • Python 기반 데이터 정제, 데이터 탐색, 피쳐 엔지니어링의 경험이 있으신 ...
# 15  • Python 프로그래밍 실무 경력 (1년 이상)• 알고리듬 기반 솔루션 개발 유...
# 16  • Python 프로그래밍 실무 경력 (1년 이상)• Transformer 기반 딥...
# 17  • Python 프로그래밍 실무 경력 (1년 이상)• 딥러닝 지식 및 개발 경험• ...
# 18  • 3년 이상의 머신러닝/Computer Vision 연구 혹은 개발 경력.• 딥러...
# 19  - 아래 조건 중 하나라도 해당하시는 분  A. LINER에 적재되는 텍스트, 비디...
# 20  • 머신러닝, 딥러닝 모델의 주요 개념들을 이해하고 계신 분• 머신러닝 논문들을 이...
# 21  - 서비스 프로그래밍 개발 역량이 있으신 분- Machine Learning 엔진 ...
# 22  • 다양한 머신러닝 알고리즘과 모델에 대한 깊은 흥미와 이해• 머신러닝을 활용해 실...
# 23  • 인공지능, 머신러닝, 딥러닝 개념을 이해하고 있으신 분• 머신러닝의 학습 종류를...
# 24  - 머신러닝, 딥러닝 등 인공지능 분야 경험- 협업툴 : Git GitHub, fi...
# 25  • Python, Go, Scala, Java, C++중 하나 이상의 언어에 능통하...
# 26  [이런 역량을 갖춘 분을 찾습니다]- CS 전공 또는 CS학부 과정에 상응하는 커리...
# 27  • 컴퓨터공학, 머신러닝 관련 분야 석사 이상의 학위를 취득하신 분• 딥러닝 프레임...
# 28  • 컴퓨터공학, 머신러닝 관련 분야 석사 이상의 학위를 취득하신 분 또는 3년 이상...
# 29  • Python에 숙련된 프로그래밍 능력과 머신러닝 라이브러리 활용 경험• 머신러닝...
# 30  • Python에 숙련된 프로그래밍 능력과 머신러닝 라이브러리 활용 경험• 머신러닝...
# 31  • 데이터 분석 및 ML에 폭넓고 깊은 지식이 요구됩니다.• 하나 이상의 데이터 분...
# 32  • 학위 취득 후 최소 1년 이상 관련경험• 컴퓨터공학/통계학/수학/산업공학 관련 ...
# 33  • 컴퓨터과학, 전자공학, 데이터과학 및 관련 분야에서 석사 학위 혹은 3년 이상 ...
# 34  • 시계열예측/이상감지/최적화 등 머신러닝 프로젝트 수행경험이 있으신 분• 프레임워...
# 35  • 학사 학위 이상 학력 소지자로서 정보 과학 및 기계 학습 분야 1~3년 경력 보...
#
#                                                  우대사항  \
# 0   • 논문을 읽고 구현한 경험이 있으신 분• Docker, k8s 등의 Contain...
# 1   • ML 관련 Low Latency API 개발 경험이 있으신 분• 머신러닝 파이프...
# 2   - 상용 딥러닝 모델 구현 경험이 있으신 분- MLflow, WandB, Neptu...
# 3   - 인공지능 업계 경험- 머신러닝 관련 분야의 석/박사 학위 또는 그에 준하는 경험...
# 4   • 머신러닝 팀을 리딩해 본 경험이 있으신 분이면 좋아요.• 머신러닝 데이터/서비스...
# 5                              • 원할한 영어 구현 (말하기 및 쓰기)
# 6   • 이공계열 석사 이상• 머신러닝 top-tier conference • 의학 주요...
# 7   [이런 역량이 있으면 더욱 좋습니다]- 유관 조직에서 테크 리드 경험을 보유하신 분...
# 8   • 금융 관련 서비스 기획, 운영 경험이 있는 분• 웹 서비스 개발 기술 이해도가 ...
# 9   • 대용량 데이터 처리가 가능한 스케일러블한 머신러닝 시스템을 구축해본 경험이 있습...
# 10                                     •\t상용 챗봇 운영 경험
# 11                                                  0
# 12  • Docker 또는 Kubernetes 기반 환경의 서비스 구축 경험이 있으면 좋...
# 13                                                  0
# 14  • EDA 경험이 있으신 분 • 데이터 관련 competition에 참가한 경험이 ...
# 15      • 딥러닝 지식 보유 • 수학 백그라운드가 강한 분 • 원활한 소통 및 협업 능력
# 16  • 머신러닝 또는 딥러닝 기반의 실무 경험• Federated Learning 유경...
# 17  • 추천 엔진 개발 유경험자• Transformer 기반 딥러닝 개발 유경험자• 원...
# 18  • 컴퓨터공학/통계학/수학 등 관련 분야 학위• Human Pose Estimati...
# 19  - 클라우드 기반으로 모델 학습을 수행할 수 있는 분- 최신 딥러닝 관련 논문을 이...
# 20  • 머신러닝/추천시스템 관련 프로젝트를 경험하셨거나 추천 알고리즘에 대한 경험을 보...
# 21  - NLP ML 엔진 개발 및 서비스 적용 경험이 다수 있으신 분- IT 계열 로그...
# 22  • 수학, 통계, 엔지니어링 전공 MS or PH.D• 머신러닝, 인공지능, 데이터...
# 23  • AI 관련 스타트업 종사 경험이 있으신 분• Cloud platform (AWS...
# 24  ## 선호하는 인재상- 책임감있게 업무를 진행하시는 분- 끊임 없이 새로운 분야를 ...
# 25  • 실제 제품/서비스에 머신러닝 기술을 적용해본 경험• 머신러닝 모델 배포 파이프라...
# 26  [이런 역량이 있으면 더욱 좋습니다]- 문제해결을 즐기고, 새로운 기술을 배우는 것...
# 27  • 비정형 텍스트 데이터의 모델링 경험이 있으신 분• NLP 오픈소스의 활용 및 C...
# 28  • 음성합성용 음성 DB구축/가공 경험을 보유하신 분• E2E 음성합성 오픈소스의 ...
# 29  • 현업 업무 및 서비스에 데이터분석/머신러닝 적용 경험• 통계 및 머신러닝 관련 ...
# 30  • 현업 업무 및 서비스에 데이터 분석/머신러닝 적용 경험• 통계 및 머신러닝 관련...
# 31  • 컴퓨터 공학, 데이터 마이닝, ML 관련 분야 학사 또는 석사 학위를 가지신 분...
# 32  • NLP 관련 딥러닝 지식 및 활용 경험• NLP 관련 솔루션 설계 및 개발 경험...
# 33  • 5년 이상의 딥러닝 프로젝트 경험 혹은 컴퓨터과학, 전자공학, 데이터과학 및 관...
# 34  • Docker/kubernetes 기반 서비스 운영 경험• 워크플로우 관리 도구(...
# 35  • 컴퓨터 과학 석사학위 또는 박사학위 소지자• 프로젝트 관리 경험• 국가보훈대상자...
#
#                                               혜택 및 복지  \
# 0   근무환경• 단순히 직장을 다닌다는 느낌보다, 우리가 믿는 바를 실현하기 위해 함께 ...
# 1   근무환경• 단순히 직장을 다닌다는 느낌보다, 우리가 믿는 바를 실현하기 위해 함께 ...
# 2   [쾌적한 업무 환경]- 쾌적한 사무실, 편안한 자유 복장- 고사양 업무 디바이스 제...
# 3   • 생일휴가 - 연차 소진 없는 휴가 1일을 제공합니다.• 탄력 출퇴근 - 8시에서...
# 4   따뜻한 프로페셔널 ABLY, 당신을 위해 아낌없이 지원해요.[몰입할 수 있는 최고의...
# 5   • 입사 시 주식연계형 보상(RSU) 지급• 완전 자율출퇴근제• 연차 및 재택근무의...
# 6   • [개발직군] 주요 논문 출판 시, 500~2,000만원 보상금• 눈치보지 않고 ...
# 7   [줌인터넷의 생활을 공개합니다]Work P+US : 업무에 온전히 몰입할 수 있도록...
# 8   성장 지원• 외부 교육 지원 (인터넷 강의, 세미나 등)• 사내 스터디 지원• 도서...
# 9   • 기본적인 버즈빌리언의 생활을 위하여,- 점심식대 지원 및 무제한 간식/음료/고급...
# 10  •\t구성원의 개인 생활 및 영역에 대한 존중•\t개개인의 상황을 최대한 배려하여 ...
# 11  1. 간식비는 회사가 전적으로 책임집니다. • pushbar 운영 (음료와 간식 3...
# 12  • 업무에 필요한 최신 기기 및 환경 제공 (Macbook Pro)• 삼성역 근처 ...
# 13                                                  0
# 14  • 자율과 효율성에 기반한 최적의 근무환경 • 잠실역 5분 거리 사무실 (롯데월드타...
# 15  • 하렉스인포텍의 연봉 제도는 기존의 연공서열 중심의 승진 및 호봉제도에 기반한 임...
# 16  • 하렉스인포텍의 연봉 제도는 기존의 연공서열 중심의 승진 및 호봉제도에 기반한 임...
# 17  • 하렉스인포텍의 연봉 제도는 기존의 연공서열 중심의 승진 및 호봉제도에 기반한 임...
# 18  • 주도적인 업무환경 및 성장 기회• 주 5일 자율출퇴근/유연근무 (주 40시간 근...
# 19  - 자율 출근 시간, 주 40시간 근무- 업계 최고 업무 장비 지원 (인당 500만...
# 20  • 최신 업무장비를 제공 합니다.• 도서구입 및 자기개발비를 지원 합니다.• 매월 ...
# 21  • 개인 별 라이프 스타일에 따른 자율 출근 (8am~10am)• 최고의 접근성 (...
# 22  아이지에이웍스는 오직 업무에만 집중할 수 있도록 다양한 복리후생 프로그램을 제공하고...
# 23  • [데일리언이 되신 것을 환영합니다!] 슬리퍼, 텀블러, 후드 집업 등 슬기로운 ...
# 24         • 재택근무• 글로벌 팀 영어 소통 • 수평적 조직 문화 • 자기계발비 지원
# 25  • 8시~11시 사이에 자율적으로 출근• 주 2~3회 재택근무 (개발조직 근무체계 ...
# 26  [이스트패밀리의 생활을 공개합니다]Work P+US : 업무에 온전히 몰입할 수 있...
# 27  • 사내 식당 (점심, 저녁 무료 제공)• 기념일 지원/행사 : 선물을 비롯한 현금...
# 28  • 사내 식당 (점심, 저녁 무료 제공)• 기념일 지원/행사 : 선물을 비롯한 현금...
# 29  • Work & Life Balance 지원을 위한 마일리지/보육 시설/카페테리아/...
# 30  • Work & Life Balance 지원을 위한 마일리지/보육 시설/카페테리아/...
# 31  더 많은 프로젝트와 일하는 방식 등이 궁금하시다면, 링크 (https://bit.l...
# 32  • 자유로운 분위기! 회식강요 안함 / 자유복장 / 자유로운 연차사용• 자녀 폴리 ...
# 33                            • 최고수준의 연봉• 유연한 유급 휴가 등
# 34  • 자율 출퇴근매일 매일 편한 시간에 출근하세요(9~10) 하루 8시간 열심히 근무...
# 35                                    • 4대 보험, 퇴직연금 등
#
#                                              기술스택 ・ 툴  \
# 0                                             [Excel]
# 1                                             [Excel]
# 2   [Github, JIRA, Slack, MySQL, Pytorch, React, R...
# 3   [Confluence, GitLab, JIRA, Slack, ObjectiveC, ...
# 4   [Github, Django, MySQL, Redis, JavaScript, Pyt...
# 5                                                   0
# 6   [Github, Pytorch, Tensorflow, Python, AWS, Doc...
# 7   [Git, Github, GitLab, Slack, Android, Django, ...
# 8   [Confluence, Git, Slack, Trello, Android, Djan...
# 9                                    [Python, Golang]
# 10                                                  0
# 11     [React, Java, Node.js, AWS, React.js, Flutter]
# 12  [Git, JIRA, Django, MySQL, JavaScript, Python,...
# 13                                                  0
# 14                                              [PHP]
# 15                [Linux, Tensorflow, Python, Docker]
# 16                [Linux, Tensorflow, Python, Docker]
# 17                [Linux, Tensorflow, Python, Docker]
# 18  [Github, Android, iOS, React, JavaScript, Kotl...
# 19  [Git, MySQL, Pytorch, React, Tensorflow, HTML,...
# 20                                                  0
# 21                          [TypeScript, AWS, NodeJS]
# 22                   [Git, C#, Python, SQL, OOP, AWS]
# 23  [Github, MySQL, PHP, Python, AWS, PostgreSQL, ...
# 24  [Git, MySQL, React, Python, AWS, Spring Framew...
# 25                                                  0
# 26  [Git, Github, Android, AngularJS, iOS, Linux, ...
# 27                                  [Python, Tableau]
# 28                                  [Python, Tableau]
# 29                           [Java, AWS, Docker, GCP]
# 30                           [Java, AWS, Docker, GCP]
# 31                                                  0
# 32  [ExtJS, VueJS, Java, JavaScript, TypeScript, j...
# 33                                                  0
# 34                      [Java, Python, Go, OpenStack]
# 35               [Git, Python, 컴퓨터 비전, 머신 비전, OpenCV]
#
#                                              지역
# 0             서울특별시 성동구 성수동1가 656-292 패스트파이브 9층
# 1             서울특별시 성동구 성수동1가 656-292 패스트파이브 9층
# 2                          서울 강남구 도곡로3길 27, 10층
# 3                 08788 서울시 관악구 남부순환로 1838, 11층
# 4                 서울특별시 서초구 강남대로 465, 교보타워 6,9층
# 5                         서울시 강남구 강남대로 636 두원빌딩
# 6                       서울 구로구 디지털로34길 43, 906호
# 7               서울특별시 서초구 서초3동 1464-30 이스트빌딩 7층
# 8                    서울특별시 영등포구 국제금융로2길 17, 13층
# 9                 서울특별시 송파구 석촌호수로 272 MY빌딩 2~5층
# 10                        서울시 중구 삼일대로 343 (위워크)
# 11                     서울특별시 여의나루로57 신송센터빌딩 13층
# 12          06168 서울 강남구 테헤란로 503 패스트파이브 삼성 3호점
# 13  경기 용인시 수지구 광교중앙로 338 광교 우미뉴브지식산업센터 A동 1011호
# 14                     송파구 올림픽로 300, 롯데월드타워 디쉐어
# 15                             서울특별시 중구 퇴계로 202
# 16                             서울특별시 중구 퇴계로 202
# 17                             서울특별시 중구 퇴계로 202
# 18                 서울특별시 서초구 서초대로 396, 강남빌딩 17층
# 19                         서울특별시 마포구 홍익로 25, 3층
# 20                    서울특별시 강남구 테헤란로107길 6 두양빌딩
# 21                     강남구 테헤란로2길 27 비전타워 1401호
# 22                  서울시 마포구 양화로 45 세아타워 15층/20층
# 23            서울시 강남구 언주로 620, 9층 (논현동, 현대인텔렉스)
# 24              서울 중구 남대문로9길 24 패스트파이브 타워 3-12층
# 25        서울특별시 용산구 서빙고로 17(한강로3가), 센트럴파크타워 10층
# 26          서울특별시 서초구 반포대로 3 이스트빌딩(서초동 1464-30)
# 27      서울특별시 강남구 논현로 72길 23, 2층 (역삼동770, 송하빌딩)
# 28      서울특별시 강남구 논현로 72길 23, 2층 (역삼동770, 송하빌딩)
# 29                  경기도 성남시 분당구 판교로 256번길 7, 넥슨
# 30                  경기도 성남시 분당구 판교로 256번길 7, 넥슨
# 31              서울특별시 영등포구 국제금융로8길 16 신영증권빌딩 9층
# 32                               서울특별시 송파구 송파대로
# 33                                          서초구
# 34            마포구 상암산로76 YTN 뉴스퀘어 16층 오케스트로 연구소
# 35                             경북 포항시 남구 청암로 77

# %%
## 아래 코드는 참고용 입니다. 꼭 안 봐도 됩니다.

# %%
#기술스텍불러오기
#info_tag.find_next_sibling().text//
list(map(lambda x:x.text,info_tag.next_element.next_element.findChild().findChildren()))
# Out:
# ['Python', 'SQL', 'Google Analytics']

# %%
info_tag_line = info_tag.next_sibling
info_tag_line.text
# Out:
# '- 매월 통신비 비용 제공- 매년 1회 건강 검진 제공- 주3일 재택 근무 가능 (협의시)'

# %%
# 회사 주소 불러오기
import json
loc = com_html.find('script',{'type':'application/ld+json'})
loc2 = dict(json.loads(loc.text))['jobLocation']['address']['streetAddress']
print(loc)
# Out:
# <script type="application/ld+json">{"@context":"https://schema.org","@type":"JobPosting","title":"데이터 분석가","description":"데이터 가공, 분석 및 시각화\n- 온라인로그/캠페인 데이터 등을 활용하여 비즈니스 이슈에 대해 가설을 수립\n- 데이터 핸들링 및 분석\n- 리포트 작성, 대시보드 기획/관리 등 시각화","url":"https://www.wanted.co.kr/wd/97358","hiringOrganization":{"@type":"Organization","name":"휴머스온","logo":"https://static.wanted.co.kr/images/wdes/0_4.5ae2c9e8.jpg"},"datePosted":"2022-07-04","industry":"IT, 컨텐츠","occupationalCategory":"Management & Business, Data Analyst,데이터 분석가","validThrough":"2022-08-01","employmentType":"FULL_TIME","jobLocation":{"@type":"Place","address":{"@type":"PostalAddress","addressRegion":"서울","addressCountry":"KR","streetAddress":"서울특별시 강남구 역삼2동 세방빌딩 10층, 12층"}},"experienceRequirements":["경력"]}</script>

# %%
#'h5'태그에는 회사 이름이 들어가 있습니다.
company_name = com_html.find('h5')
company_name.text
# Out:
# 머큐리프로젝트

# %%
#info_tahg는 info_list에 들어있는 텍스트와 같은 h6태그를 찾음
info_tag = com_html.find('h6', string = info_list[0])
info_tag.nextSibling.text

# %%
#'주요업무', '자격요건', '우대사항', '혜택 및 복지' 불러오기
apply = h6.next_sibling
print(apply.text)
#print(apply.text)
#a = apply.text.split('-')
#print(a)
# Out:
# - 데이터 분석에 대한 팀이 존재 하지 않는 상황으로 분석을 위한 초기 인프라 구축이 가능하신분- 3년 이상 실질적인 비즈니스 문제를 해결하기 위한 기법 또는 머신러닝을 적용한 경력을 보유한 분- 서비스를 개선하는 데 도움이 되는 논문이나 기술들을 빠르게 학습하여 프로토타이핑할 수 있는 문제해결 능력을 갖추신 분- 지원시 포트폴리오 필수 첨부(PPT, PDF, URL 등 자유형식)

# %%
# Out:
# Mounted at /content/gdrive

# %%
#pip install pandas

# %%
# import pandas as pd

# file = pd.read_csv(r'/content/gdrive/My Drive/Colab Notebooks/txt_to_csv.txt')
# new_csv_file = file.to_csv(r'/content/gdrive/My Drive/Colab Notebooks/txt_to_csv.csv', encoding='utf-8')

# %%
df.duplicated()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-0f46bb3bd87f> in <module>()
# ----> 1 df.duplicated()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6198
#    6199         vals = (col.values for name, col in self.items() if name in subset)
# -> 6200         labels, shape = map(list, zip(*map(f, vals)))
#    6201
#    6202         ids = get_group_index(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in f(vals)
#    6171
#    6172         def f(vals) -> tuple[np.ndarray, int]:
# -> 6173             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6174             return labels.astype("i8", copy=False), len(shape)
#    6175
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     760
#     761         codes, uniques = factorize_array(
# --> 762             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763         )
#     764
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     562     table = hash_klass(size_hint or len(values))
#     563     uniques, codes = table.factorize(
# --> 564         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565     )
#     566
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df['지역'] = df['지역'].apply(lambda x: dict(json.loads(x.text))['jobLocation']['address']['streetAddress'])

# %%
def name(x):
  if x:
    return x.text

df['회사이름'] = df['회사이름'].apply(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-141e5bf8d849> in <module>()
#       3     return x.text
#       4
# ----> 5 df['회사이름'] = df['회사이름'].apply(name)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-141e5bf8d849> in name(x)
#       1 def name(x):
#       2   if x:
# ----> 3     return x.text
#       4
#       5 df['회사이름'] = df['회사이름'].apply(name)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
keyword_list[df[df['회사이름'].isnull()].index[0]-1:df[df['회사이름'].isnull()].index[0]+2]
# Out:
# ['/wd/65289', '/wd/90183', '/wd/63921']

# %%
df
# Out:
#                   회사이름                                               주요업무  \
# 0                 데키스트  • IoT 단말기 개발 (센서, OTA,I2C,SPI LCD, USB, LORA, ...
# 1                드림에이스  1. 스마트시티 IoT 디바이스 기구/디자인 설계2. 시제품 제작 및 양산 팔로업3...
# 2                드림에이스  1. 디지털 및 아닐로그 회로 설계 및 P/L 작성2. 디지털 및 아닐로그 PCB ...
# 3                드림에이스  1. 개발 문서 및 생산 자료 검토 (BOM , 회로도 ,거버데이터) 2. 제조자료...
# 4                드림에이스  1. IoT, Digital Product 디자인 - 모빌리티 및 생활가전 제품 디...
# 5                드림에이스  1. 기구 설계 및 개발 (2D & 3D) - 생활가전 제품 관련2. 개발 문서 작...
# 6                  정육각  • 정육각 조리 기기(IoT)와 연계된 앱 서비스의 초기 기획 및 프로젝트 관리 -...
# 7                  정육각  • 정육각 IoT기기의 임베디드 SW 개발 - IoT기기의 MCU기반 컨트롤 보드와...
# 8                  엔텔스  1. oneM2M 표준 프로토콜 기반 IoT플랫폼 기능 개발- 개발환경 : Cont...
# 9                  티오더  • 여러 벤더의 POS 장비와 티오더 서비스와의 연동관련 개발 업무• 여러 IoT ...
# 10       아이엠랩(I.M.LAB)  - 응급의료 교육 IoT(소형/저전력/무선) HW 개발- 최신 HW 기술 검증 및 ...
# 11  에스랩아시아(s.Lab Asia)  • 데이터로거(디지털온도측정기) IoT 제품 및 플랫폼 서비스에 대한  제안과 사업...
# 12   이큐브랩 (Ecube Labs)  - IoT 기기와 통신하는 서버 개발 및 유지 보수- LoRaWAN 플랫폼과 통신하...
# 13          고퀄(GOQUAL)  [고퀄의 Frontend 개발자는 어떤 일을 하나요?] 1. '헤이홈 스퀘어' 신규...
# 14          고퀄(GOQUAL)  [고퀄의 Android 개발자는 어떤 일을 하나요?]1. 신규 헤이홈 Android...
# 15          고퀄(GOQUAL)  [고퀄의 iOS 개발자는 어떤 일을 하나요?]  1. 신규 헤이홈 iOS 앱 개발고...
# 16          고퀄(GOQUAL)  [고퀄의 Backend 개발자는 어떤 일을 하나요?] 1. '헤이홈 스퀘어' 신규 ...
# 17                 모빅랩  • IoT 시스템 서비스 포탈 개발• IoT 시스템 브로커 엔진 개발• IoT 디바...
# 18             야놀자클라우드  [ ITS (IoT Solution) 실 소개 ]야놀자클라우드는 IoT 기술과 클라...
# 19           피플앤드테크놀러지  • AIoT 기반 플랫폼 서비스 기획• 스마트헬스케어 응용 서비스 기획• 자사 솔루...
# 20       럭스로보(LUXROBO)  • IoT 제품 Spec 에 맞는 HW Research 및 업체 컨택• IoT HW...
# 21       럭스로보(LUXROBO)  [사업 발굴 및 기획 (산업 분석 및 주요 전략 수립)]• 잠재 시장 및 고객 니즈...
# 22                  잉클  • 산업용 IoT Edge 엔진 개발• 산업용 통신 프로토콜 구현 (e.g. Eth...
# 23                 메가존  • AWS IoT 서비스를 활용한 컨설팅, 데모, 개발• 고객사의 요구사항을 이해하...
# 24              퓨어스페이스    - 임베디드 SW 및 하드웨어 개선- 적합한 IoT 플랫폼 검토- IoT 플랫폼 연계
# 25                 하이비  • IoT 서비스 API 개발• IoT 사용자 응용 개발• 신규 IoT 모듈 SDK...
# 26             한컴인텔리전스  • 자체 개발한 IoT 플랫폼을 기반으로 한 서비스의 개발 및 개선• 애플리케이션 ...
# 27             한컴인텔리전스  • 자체 개발한 IoT 플랫폼을 기반으로 한 서비스의 설계 및 개발• 제품 개발을 ...
# 28                아이마스  • 차량용 IoT 단말기 장착, 탈거, 유지보수• 차량설치정보 DB구축• 현장 아웃...
# 29                 코웨이  - IoT Backend 플랫폼 개발 업무- IoCare 앱 관련 플랫폼 개발 업무...
# 30           아스크스토리디에스                                       • IoT 시스템 개발
#
#                                                  자격요건  \
# 0   • 임베디드 시스템 이해• C언어 상급• 통신 모듈 사용 경험 (BLE,WIFI,L...
# 1   1. 유관 업무 5년 이상 경력자 2. 양산 설계 경험자3. 제품 인증 경험자4. ...
# 2   1. 전자 회로 설계 경력 10년 이상 경력자2. 회로도 작성 툴 사용 기술 (or...
# 3      1. 유관 업무 5년 이상 경력자2. 생산기술 업무 경험자3. 외주관리 업무 경험자
# 4   1. 제품 디자인 관련 경력 5년 이상 경력자 2. 신제품 컨셉 제안 경험자3. 제...
# 5   1. 유관 경력 5년 이상 경력자2. CAD/CAM 능숙자 (2D & 3D)3. 디...
# 6   • 앱 서비스 기획 3년 이상 경력 보유자• User, Tech, UX/UI 트렌드...
# 7   • Embedded SW 개발경험이 있으신 분• 빠른 학습속도를 가지고 정육각과 함...
# 8   • 학력 : 무관• 경력 : 경력 6년 이상• Java/JSP, Spring fra...
# 9   • 학력 : 4년대 졸업• 경력 : 실무 경력 1년 이상 ~ 7년 미만• Softw...
# 10  ✻ 이기종 센서 탑재 HW 회로설계 및 Artwork 가능자✻ 저전력 무선제품 개발...
# 11  • IT 엔지니어링 관련 경력 / 플랫폼 서비스 세일즈 3년 이상• IT 엔지니어,...
# 12  ## 자격요건- 만 5년 이상의 Back-end 개발 경험 또는 이에 준하는 지식 ...
# 13              [이런 능력이 필요해요!]1. Frontend 개발 경력 3년 이상
# 14  [이런 능력이 필요해요!] 1. 포괄적인 고퀄 IoT 서비스 구조 이해 2. 점진적...
# 15  [이런 능력이 필요 해요!]1. Swift를 이용한 iOS 앱 개발 경력 3년 이상...
# 16  [이런 능력이 필요 해요!]1. Backend 개발 경력 3년 이상2. Java, ...
# 17  • 개발 경력 5년 이상 JavaScript에 대한 전문적인 개발 역량• Node....
# 18  • 5년 이상의 Back-end 개발 경력 또는 그에 준하는 역량을 보유하신 분• ...
# 19       • MS Powerpoint 문서 작성 및 발표 능력• 업무 기반 의사소통 스킬
# 20  • Schematic Design, MCU, DSP 및 각종 센서 interface...
# 21  • 학사이상, 전공무관• 신규 사업 전략 기획부터 사업화 실행까지 경험 보유자  (...
# 22  • 네트워크 프로그램 관련 개발 경력이 있는 분• 네트워크 라우팅에 대해 잘 아는 ...
# 23  • AWS 활용 지식 보유• AWS IoT Core, Lambda, DynamoDB...
# 24  아래 요건 중 일부 요건 보유하신 분 - 임베디드 시스템 개발 경험- 디바이스 - ...
# 25  • (대졸자) 전기/전자/컴퓨터 또는 유사학과 전공자• (고졸자) 전기/전자/컴퓨터...
# 26  • Java, Database(RDMBS, TSDB), Docker 실무 개발 경험...
# 27  • Java, Database(RDMBS, TSDB), Docker 실무 개발 경험...
# 28                     • 경력 : 무관 (신입도 지원가능)• 운전면허 소지자
# 29  - Spring Boot, ORM 기반의 Backend 개발 경험 보유(5년이상)-...
# 30        • IT 개발경력 1년 이상• 자료구조/알고리즘에 대한 기본적인 이해• 책임감
#
#                                                  우대사항  \
# 0   • Microchip , TI 반도체 제품 사용 경험• 무선 통신 기반의 프로젝트 ...
# 1   1. 기계공학 계열 전공자2. 3D 프린팅 경험자[이러한 동료와 함께 하고 싶습니다...
# 2   1. 전자 및 전기, 산업 공학 전공자[이러한 동료와 함께 하고 싶습니다!]1. 회...
# 3   1. ISO 품질 시스템 업무 경험자2. 전기/전자계열 전공자 [이러한 동료와 함께...
# 4   1. 산업 디자인, 제품 디자인 전공자 또는 관련 업무 전공자 [이러한 동료와 함께...
# 5   1. 전자, 기계 및 공학 전공자2. 기구 설계 관련 자격증 소유자3. ISO 품질...
# 6   • IoT 기기 관련 모바일 앱의 기획 / PM 경험 있으신 분• 초기 기획 - 구...
# 7   • 언어에 대한 경험이 6개월 이상인 분• 소프트웨어 품질에 관심이 많고, 소프트웨...
# 8   • Spring Boot, Spring Famework 에 대한 이해도 보유 / 개...
# 9   • 여러 IoT 및 로봇 장비 연동 경험이 있으신 분• 여러 벤더의 POS 장비와 ...
# 10  ✻ 하드웨어 개발 경력(2년이상) 우대✻ 관련 전공 졸업자(전자/전파 등)✻ 국내외...
# 11              • IT 인프라 컨설팅 및 솔루션  경험 보유자• 영어 회화 가능자
# 12  ## 우대사항- The Things Stack 과 같은 LoRaWAN 플랫폼을 이용...
# 13  [이런 것도 잘 하시면 더더욱 좋아요!]1. Microservices 아키텍처에 대...
# 14  [이런 것도 잘 하시면 더더욱 좋아요!]1. 사용자 중심 IoT 제품 UX/UI 최...
# 15  [이런 것도 잘 하시면 더더욱 좋아요!] 1. 사용자 중심 IoT 제품 UI/UX ...
# 16  [이런 것도 잘 하시면 더더욱 좋아요!]1. Microservices 아키텍처에 대...
# 17  • MSA 기반 프로젝트 경험자• Mqtt broker를 활용하는 시스템 개발 경험...
# 18  • 언어와 환경에 구애 받지 않고 서비스를 구축할 수 있는 능력• AWS Serve...
# 19          • IoT, IoMT, AIoT 기반 서비스 기획 경험• IT 관련 전공자
# 20  • EAGLE or Altium 가능• Fusion 360 가능• 아날로그 회로설계...
# 21  • 신성장 IT 산업 및 4차 산업 등에 대한 높은 관심 및 이해도• 스마트홈 솔루...
# 22  • 오픈소스 컨트리뷰터• 산업용 프로토콜 개발 경험이 있는 분• QA 단계를 포함하...
# 23  • Message Broker 서버 설계(Topic Design) 및 운영 경험• ...
# 24                                  - IoT 관련 개발 PM 경험
# 25  • Java 등 OOP에 능숙한 자• 산업용 통신 프로토콜 개발 경험자(BLE, M...
# 26  • Cloud(MS Azure, AWS)에서 서비스 개발 경험이 있으신 분• 상용 ...
# 27  • Cloud(MS Azure, AWS)에서 서비스 개발 경험이 있으신 분• 상용 ...
# 28  • FMS(차량관제서비스) 유경험자• 차량 CAN통신 및 OBD 관련 유경험자• 자...
# 29  - 대용량 트래픽 기반 서비스 경험 보유- DevOps, CI/CD 경험, Cont...
# 30  • 아두이노 개발 유경험• Node.js 개발 유경험• Dashboard UI 개발...
#
#                                               혜택 및 복지  \
# 0   1. 근무형태: 정규직(수습기간)-2개월2. 근무일시: 주 5일(월~금) 오전 9:...
# 1   [더 나은 Work Place를 위해]• 좋은 장비를 갖춰야 일할 맛이 난다.- 업...
# 2   [더 나은 Work Place를 위해]• 좋은 장비를 갖춰야 일할 맛이 난다.- 업...
# 3   [더 나은 Work Place를 위해]• 좋은 장비를 갖춰야 일할 맛이 난다.- 업...
# 4   [더 나은 Work Place를 위해]• 좋은 장비를 갖춰야 일할 맛이 난다.- 업...
# 5   [더 나은 Work Place를 위해]• 좋은 장비를 갖춰야 일할 맛이 난다.- 업...
# 6   1. 근무조건• 스마트하고 성격까지 훌륭한 동료들• 신논현역 5분 거리에 위치한 접...
# 7   1. 근무조건• 스마트하고 성격까지 훌륭한 동료들• 신논현역 5분 거리에 위치한 접...
# 8   • nDay  : 매주 금요일 오후 4시 조기 퇴근• 통합복리비 지급 : 100만원...
# 9   - 원하시는 사양의 컴퓨터 (맥북 가능) 지급해 드립니다. 업무 효율만 생각합시다!...
# 10  • 근무 형태 - 유연근무 (8:30~10시 출근, 17:30~19시 퇴근), 자유...
# 11  • 에스랩아시아는 평균연령 34세의 젊은 기업으로 수평적인 근무 환경을 지향합니다....
# 12  • 직무관련 도서 무제한 지원 • 업무용 장비 지급(최신) • 경조사 금액 지원 및...
# 13  [고퀄은 이런 문화를 지향합니다]- 모두가 서로 업무적으로 믿을 수 있고 함께 성장...
# 14  [고퀄은 이런 문화를 지향합니다]- 모두가 서로 업무적으로 믿을 수 있고 함께 성장...
# 15  [고퀄은 이런 문화를 지향합니다]- 모두가 서로 업무적으로 믿을 수 있고 함께 성장...
# 16  [고퀄은 이런 문화를 지향합니다]- 모두가 서로 업무적으로 믿을 수 있고 함께 성장...
# 17  [근태]• 자유로운 업무 환경 (복장 자율, 자유로운 연차 사용)• 맞춤형 출퇴근제...
# 18  • 상시 원격근무 • 야놀자 앱 포인트 100만원• 중식비 제공(1일 1만원) • ...
# 19  “아~무 걱정 말고 일만 하실 수 있도록”• Intellij 개발툴 및 업무에 필요...
# 20  • 8시~10시 중, 출근시간 선택• 체력단련비(휘트니스) 지원• 도서 구입 지원•...
# 21  • 8시~10시 중, 출근시간 선택• 체력단련비(휘트니스) 지원• 도서 구입 지원•...
# 22  일에 몰입하는 만큼, 삶에 충실하게 성장할 수 있도록 01. 개인 존중가장 일하기 ...
# 23  • 하루 8시간, 야근을 지양하고 근무시간에 집중하는 문화 정착    (혹시라도 야...
# 24        • 경력에 따른 협의, 업계 평균 대비 우수한 대우• 자유로운 연차 사용 가능
# 25  [Compensation Package]4대 보험, 퇴직금, 연차업계 최고의 pro...
# 26  • 신규입사자 웰컴박스(각종 사무용품)• 포상제도(장기근속, 특허, 인텔리전스인상,...
# 27  • 신규입사자 웰컴박스(각종 사무용품)• 포상제도(장기근속, 특허, 인텔리전스인상,...
# 28  • 자율 출근제 : 날마다 새로운 아침 8:30 ~ 10:00 사이 자유롭게 출근해...
# 29                                        * 회사 내규에 따름
# 30  • 여름 휴가비 지원• 프로젝트 기반 성과급 지급• Refresh Day!! 매월 ...
#
#                                              기술스택 ・ 툴  \
# 0   [Git, VueJS, JavaScript, PHP, Python, IoT, AWS...
# 1   [생산, 품질 향상, 품질 관리, 설계, 제품 품질, 품질 관리, 공정 개발, 생산...
# 2                                                   0
# 3   [생산, 품질 향상, 품질 관리, 설계, 제품 품질, 품질 관리, 공정 개발, 생산...
# 4   [디자인 관리, HCI, 서비스 디자인, Sketch, 웹 디자인, CSS, 디자인...
# 5                                                   0
# 6                                                   0
# 7                                   [Node.js, Golang]
# 8   [Linux, UNIX, JSP, Spring Framework, JPA, JSP ...
# 9                     [Git, Delphi, AWS, Windows 서비스]
# 10  [Git, Github, Android, Firebase, iOS, MySQL, R...
# 11                                                  0
# 12     [Git, iOS, Node.js, TypeScript, IoT, AWS, WAN]
# 13  [Git, Github, iOS, Linux, MySQL, React, C / C+...
# 14  [Git, Github, iOS, Linux, MySQL, React, C / C+...
# 15  [Git, Github, iOS, Linux, MySQL, React, C / C+...
# 16  [Git, Github, iOS, Linux, MySQL, React, C / C+...
# 17  [Linux, VueJS, JavaScript, ElasticSearch, Node...
# 18                                [React, TypeScript]
# 19                              [사업 계획, 제품 개발, 제품 기획]
# 20                                                  0
# 21                                    [Communication]
# 22  [Git, Github, Flask, GraphQL, MongoDB, Pytorch...
# 23               [Azure, React, TypeScript, AWS, GCP]
# 24                                                  0
# 25                         [IoT, C, C++, API, API 개발]
# 26  [Git, Azure, Redis, Java, Python, AWS, Docker,...
# 27  [Git, Azure, Redis, Java, Python, AWS, Docker,...
# 28                                                  0
# 29                                       [Linux, AWS]
# 30                    [React, JavaScript, AR, NodeJS]
#
#                                               지역
# 0                              경기 용인시 기흥구 흥덕1로13
# 1                   서울 성동구 성수일로 19 유한타워 1, 2, 3층
# 2                   서울 성동구 성수일로 19 유한타워 1, 2, 3층
# 3                   서울 성동구 성수일로 19 유한타워 1, 2, 3층
# 4                   서울 성동구 성수일로 19 유한타워 1, 2, 3층
# 5                   서울 성동구 성수일로 19 유한타워 1, 2, 3층
# 6                               강남구 강남대로 112길 32
# 7                               강남구 강남대로 112길 32
# 8                    서울 강남구 학동로 401(청담동 금하빌딩) 8층
# 9                 서울 구로구 디지털로33길 48 대륭포스트타워7차 9층
# 10            서울특별시 서초구 남부순환로347길 53, 파이원빌딩 201호
# 11                 강남구 영동대로 511 703호(삼성동,트레이드타워)
# 12                            서울특별시 구로구 디지털로 300
# 13         서울특별시 금천구 가산디지털1로 165. 가산비지니스센터 1301호
# 14         서울특별시 금천구 가산디지털1로 165. 가산비지니스센터 1301호
# 15         서울특별시 금천구 가산디지털1로 165. 가산비지니스센터 1301호
# 16         서울특별시 금천구 가산디지털1로 165. 가산비지니스센터 1301호
# 17                                연수구 컨벤시아대로 204
# 18                         서울특별시 강남구 테헤란로108길 42
# 19                             삼성로95길 27 영창빌딩 5층
# 20                   서울시 서초구 강남대로 311 한화생명빌딩 13층
# 21                   서울시 서초구 강남대로 311 한화생명빌딩 13층
# 22  경기도 화성시 동탄기흥로 560 (영천동) 동익미라벨타워 806호 주식회사 잉클
# 23                         강남구 논현로 85길 46, 메가존빌딩
# 24                   금천구 디지털로 121, 에이스가산타워 2001호
# 25                경기 성남시 분당구 대왕판교로 660 유스페이스1 B동
# 26             경기도 성남시 분당구 대왕판교로644번길 49 한컴타워 3층
# 27             경기도 성남시 분당구 대왕판교로644번길 49 한컴타워 3층
# 28                                      아차산로 355
# 29                         서울특별시 구로구 디지털로 26길 38
# 30           매헌로 16, (하이브랜드빌딩) AI 양재허브 13층 1303호

# %%
df.to_csv("wanted.csv", sep=',', encoding = "UTF-8")

# %%
df.to_excel("wanted_IoT.xls")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """Entry point for launching an IPython kernel.

# %%
pd.read_csv("wanted.csv")
# Out:
#     Unnamed: 0                                       회사이름  \
# 0            0                              <h5>에비드넷</h5>
# 1            1                           <h5>머큐리프로젝트</h5>
# 2            2                              <h5>휴머스온</h5>
# 3            3                             <h5>더블유클럽</h5>
# 4            4  <h5>파이프트리스마트팜(PAIPTREESmartFarmInc.)</h5>
# ..         ...                                        ...
# 68          68                                <h5>컬리</h5>
# 69          69                             <h5>라인게임즈</h5>
# 70          70                     <h5>플라이셔(Flysher)</h5>
# 71          71                     <h5>콘텐츠웨이브(wavve)</h5>
# 72          72                     <h5>콘텐츠웨이브(wavve)</h5>
#
#                                                  주요업무  \
# 0          • 의료 빅데이터 분석(데이터 전처리, 통계분석)• 의료 빅데이터 연구 기획
# 1   - AdTech 도메인에 특화된 데이터 분석 및 개발- 머신러닝/데이터 분석 기술을...
# 2   데이터 가공, 분석 및 시각화- 온라인로그/캠페인 데이터 등을 활용하여 비즈니스 이...
# 3   • 서비스 지표 상승 및 문제 해결을 위한 데이터 기반의 인사이트 제공• 데이터 분...
# 4   - 농장 환경 및 생체 데이터 분석 및 주제 발굴- 정형 및 비정형 데이터(영상, ...
# ..                                                ...
# 68  • 분석을 위한 데이터를 설계 및 적재하고 대시보드, 알람 등의 프로덕트로 만들어 ...
# 69  • 게임 로그 분석 및 통계 분석• 게임 데이터 분석을 통한, 문제점 파악 및 개선...
# 70  • 로그 설계 : 게임을 플레이하며 의사결정에 필요할 정보를 DB에 어떻게 쌓을지 ...
# 71  • 데이터 분석/이해에 기반하여, 가입자 매출/증대를 위한 CRM기획 및 운영   ...
# 72  - Wavve 서비스에서 생성되는 데이터 분석 업무- Wavve 데이터 이용한 머신...
#
#                                                  자격요건  \
# 0   • 학사이상(통계, 수학, 산업공학, 컴퓨터 공학, 생명과학, 의료정보학 등)• 병...
# 1   - 데이터 분석에 대한 팀이 존재 하지 않는 상황으로 분석을 위한 초기 인프라 구축...
# 2   - 데이터 분석 경험 1년 이상, 통계지식 보유- 마케팅전략/디지털마케팅전략/소비트...
# 3   • 단순한 아이디어 차원이 아닌 실질적인 Action 을 위한 구체적인 인사이트를 ...
# 4   - 통계(빈도, 베이지안) 분석 및 모델링 경험- Shell, SQL 중급 이상, ...
# ..                                                ...
# 68  • 유관 업무 경력 2년 이상을 선호합니다. 다만 기본 스킬이 충분하다면 경력이 조...
# 69  • 관련 경력 3년 이상  • 게임에 대한 열정과 및 게임 산업에 대한 이해가 있으...
# 70  • 유관 업무 경력 3~5년인 분• SQL(Redshift)에 능숙한 분• 통계 지...
# 71  • 데이터 분석 유관 경력 7년 이상자• 데이터기반 가설수립 및 문제해결 역량• S...
# 72  - 데이터 분석 업무 경험 / 3년 이상- Python 개발 경험- Linux, R...
#
#                                                  우대사항  \
# 0   • SAS, SPSS 등 분석툴 사용 가능• Python 사용 가능• 의학논문 작성...
# 1   - AdTech 도메인에 대한 지식을 보유하신 분- SQL을 능숙하게 다루실수 있는...
# 2   - 통계 지식 보유- 데이터 엔지니어 및 데이터 사이언티스와 협업 능력 및 경험 보...
# 3   • ELK (Elastic Search, Kibana) 활용 경험이 있으신 분• G...
# 4   - 통계 및 ML 관련 분야 석/박사 학위 또는 그에 준하는 경험- 로그 수준의 데...
# ..                                                ...
# 68  • 커머스, 물류 또는 로그 분석 프로젝트의 경험이 있으신 분• 커머스, 물류 분야...
# 69  • 게임 업계 혹은 타 업계 데이터 분석 실무 경험• R 혹은 Python을 이용한...
# 70  • 직무 관련 전공자 (컴퓨터공학/통계/수학 등)• Cloud(AWS 등) 개발 환...
# 71                           • 구독서비스 업계 경력(OTT, 뮤직 등)
# 72  - Apache Spark 기반 데이터 처리 개발 경험- User-Segment, ...
#
#                                               혜택 및 복지  \
# 0   [Work]• 시차출퇴근제도(8시~10시 출근)• 고사양 최신 업무용 PC 지원• ...
# 1   - 매월 통신비 비용 제공- 매년 1회 건강 검진 제공- 주3일 재택 근무 가능 (...
# 2   ＜업무에만 집중 할 수 있는 근무환경을 만들고자 노력합니다＞ * 선릉역 3번출구 도...
# 3   ■W 기업문화- 대표를 포함하여 전직원 영어 닉네임 사용 (수평적인 사내 분위기)-...
# 4   - 8~10시 자율 출근- 4대보험 / 퇴직금 별도 지급- 점심 식대 지원 (1일 ...
# ..                                                ...
# 68  ✔모두가 집중하고 성장할 수 있도록, 최적의 근무 환경을 제공해요✔• 리프레시도 필...
# 69  • 연 1회 프리미엄 건강검진 • 사내 전신 마사지실 및 헬스장• 사내 복지시설 내...
# 70  [우리는 성과를 공유합니다]• 동종업계 상위 수준 연봉 보장• 각종 인센티브 제공•...
# 71  “워라밸–Work & Life Balance” 일과 삶의 균형이 있는 회사 • 코로...
# 72  “워라밸–Work & Life Balance” 일과 삶의 균형이 있는 회사 • 원격...
#
#                                              기술스택 ・ 툴  \
# 0                      ['Python', 'R', 'SAS', 'SPSS']
# 1                                                   0
# 2               ['Python', 'SQL', 'Google Analytics']
# 3   ['Firebase', 'R', 'SQL', 'Excel', 'Google Anal...
# 4   ['Git', 'Linux', 'MySQL', 'C#', 'Node.js', 'VB...
# ..                                                ...
# 68  ['Python', 'R', 'SQL', 'Data Analysis', 'Table...
# 69                                                  0
# 70                                                  0
# 71  ['SAS', 'SQL', 'Excel', 'Google Analytics', 'T...
# 72  ['Asana', 'Confluence', 'JIRA', 'GraphQL', 'Ha...
#
#                                  지역
# 0     경기도 성남시 분당구 판교로 323 벤처포럼빌딩 5층
# 1   서울시 강남구 봉은사로 38길 13, 3층, 4층, 5층
# 2      서울특별시 강남구 역삼2동 세방빌딩 10층, 12층
# 3         서울특별시 강남구 선릉로 428 (위워크타워)
# 4          서울특별시 강남구 봉은사로 125 리스트빌딩
# ..                              ...
# 68               서울특별시 강남구 테헤란로 133
# 69            서울 강남구 테헤란로 218 AP 타워
# 70             강남구 테헤란로 223 큰길타워 8층
# 71           서울 영등포구 여의나루로 60 포스트타워
# 72           서울 영등포구 여의나루로 60 포스트타워
#
# [73 rows x 8 columns]

# %%
pd.read_csv("머신러닝엔지니어.csv")
# Out:
#     Unnamed: 0                    회사이름  \
# 0            0        스캐터랩(Scatterlab)
# 1            1        스캐터랩(Scatterlab)
# 2            2                      룩코
# 3            3                    액션파워
# 4            4               에이블리코퍼레이션
# 5            5                     몰로코
# 6            6                    메디웨일
# 7            7         에잇퍼센트(8PERCENT)
# 8            8               줌인터넷(ZUM)
# 9            9            버즈빌(buzzvil)
# 10          10  마인드로직 (Mindlogic Inc.)
# 11          11                      푸시
# 12          12          코딧(CODITCorp.)
# 13          13                     디쉐어
# 14          14                    위즈코어
# 15          15           아우름플래닛(LINER)
# 16          16                     클라썸
# 17          17              핏펫(Fitpet)
# 18          18       아이지에이웍스(IGAWorks)
# 19          19                    플라스크
# 20          20                   데일리펀딩
# 21          21            의식주컴퍼니(런드리고)
# 22          22                    하이로컬
# 23          23                  하렉스인포텍
# 24          24                     NaN
# 25          25                  하렉스인포텍
# 26          26         이스트소프트(ESTsoft)
# 27          27                    빅픽처팀
# 28          28                    빅픽처팀
# 29          29                   뱅크샐러드
# 30          30            넥슨코리아(NEXON)
# 31          31            넥슨코리아(NEXON)
# 32          32                 코리아폴리스쿨
# 33          33               엘비스(LVIS)
# 34          34                   오케스트로
# 35          35                 포항공과대학교
#
#                                                  주요업무  \
# 0   1) 데이터 전처리 및 모델 학습    Keywords: Python, Tensor...
# 1   1) 데이터 전처리 및 모델 학습    Keywords: Python, Tensor...
# 2   - 의류 이미지 속성 추출/탐지 및 이미지 검색 모델 학습- 딥 러닝 알고리즘 개발...
# 3   연구했던 분야를 고려하여 액션파워에서의 연구 주제를 정합니다.[음성, 음향 관련 연...
# 4   • 개인화 추천, 랭킹 시스템 개발을 개발해요.• CTR, 재고 등 시계열 예측 시...
# 5   • 머신러닝 팀 구성 및 리딩• 다양한 비즈니스 어플리케이션을 위한 확장된 머신러닝...
# 6   • 안저이미지로 안과질환을 판독하는 Robust 한 AI모델개발• 다양한 Sourc...
# 7   • 신용평가 모형을 개발합니다.• Fraud Detection 모형을 개발합니다.•...
# 8   [이런 업무를 담당합니다]- 줌인터넷의 검색 포털인 줌닷컴과 금융 관련 서비스인 줌...
# 9   버즈빌의 머신러닝 리드는 노출형 광고팀에 소속되어 광고주들에게 최상의 광고 성과를 ...
# 10  Python, Machinelearning 자연어 처리 및 챗봇용 신경망 구현 (의...
# 11               • 뉴스 기사 및 주식 데이터 분석• 뉴스 기사 추천시스템 개발"
# 12  • 법률 및 규제 번역 NMT 모델을 개발합니다.• 기업 및 산업별 추천 시스템을 ...
# 13  뛰어난 동료들과 함께 다양한 문제들에 대해 적극적으로 해결해 나가실 분을 찾습니다....
# 14  • 제조, 에너지 산업에서 발생하는 문제를 기계 학습 문제로 구체화• 구체화한 문제...
# 15  - 다양한 모달리티의 컨텐츠에서 피쳐를 추출하고 이를 기반으로 추천 시스템 발전- ...
# 16  - 서비스 내 다양한 데이터를 활용한 Machine Learning 엔진 개발 및 ...
# 17  구매 데이터와 동물병원 영수증 진료내역, 구강검사키트 검진 데이터와 사용자가 등록한...
# 18  • 실제 유저들의 행동 모델과 제품 분석은 위한 머신러닝, 데이터 마이닝 알고리즘 ...
# 19  • 3D Human Pose Estimation 관련 연구 및 개발• 머신러닝 모델...
# 20                  • 머신러닝 기반의 비정형 데이터 분석 모델을 구축 합니다.
# 21  • 의식주컴퍼니에 있는 수백만 장의 의류 데이터로부터 카테고리, 넥라인, 소재, 질...
# 22  - Machine learning lead    - Why you’ll like w...
# 23  • 디지털 나(Digital Me) 알고리듬 개발 • 사용자의 상태를 파악하여 적절...
# 24                                                  0
# 25  • 자연어처리 딥러닝 기반 추천엔진 솔루션 개발• 다국어 구매 기록을 활용한 초개인...
# 26  [이런 업무를 담당합니다]- Vision 머신러닝/딥러닝 알고리즘 개발 및 서비스화...
# 27         • 한국어 대화 모델 연구 및 개발• 한국어 자연어 모델링• 문제 생성 작업
# 28  • Acoustic Model 연구 및 개발• Neural Vocoder 연구 및 ...
# 29  • 뱅크샐러드 서비스에 적용되는 ML 모델을 배포하고, 운영하고, 개선해 나갑니다....
# 30  • 머신러닝 모델의 실제 프로덕션 환경 적용• 도메인 문제 해결을 위한 모델 개발•...
# 31  • 머신러닝 모델의 실제 프로덕션 환경 적용• 도메인 문제 해결을 위한 모델 개발•...
# 32  • 자연어처리 (NLP) 부문 인공지능 서비스 연구 및 개발• 질의응답, 기계독해,...
# 33  • 최신의 머신 러닝 알고리즘을 이용한 인공 지능 기반의 의료 진단 시스템 디자인•...
# 34  • 인공지능 기반 클라우드 최적화 솔루션(AIOps) SYMPHONY A.I. 개발...
# 35  • 중소기업 트레이닝 프로그램 참여 지원, 기술 지원, 새로운 공정 도입 및 트레이...
#
#                                                  자격요건  \
# 0   • Python 기반 개발에 능숙하신 분• Pytorch, Tensorflow 를 ...
# 1   • 관련 업무에 5년 이상 경험이 있으신 분• Python 기반 개발에 능숙하신 분...
# 2   - Python 언어로 원하는 것을 개발/구현 가능하신 분- DL Framework...
# 3   • 필요 역량- 자동화를 좋아하셔서, 귀찮고 반복적인 것들은 컴퓨터에게 시키고, 그...
# 4   • 머신러닝 관련 업무 경력이 5년 이상이거나, 그에 준하는 역량을 갖고 계신 분을...
# 5   • 컴퓨터공학 또는 관련 분야 석사/박사 학위• 머신러닝, 딥러닝 관련 분야 6년 ...
# 6   • 머신러닝/의학논문 작성 경험• 의료 인공지능 개발 프로젝트 개발경험• 의학통계분...
# 7   • 관련 업무에 3년 이상 경험이 있으신 분• Python과 머신러닝 프레임워크를 ...
# 8   [이런 역량을 갖춘 분을 찾습니다]- 머신러닝을 활용하여 서비스의 문제를 해결한 경...
# 9   • 팀 리드 경험이 있습니다.• 딥 러닝 및 전통적인 머신러닝 주제들에 대해 잘 이...
# 10  •\tPytorch 프레임워크 사용 경험•\t자연어처리, 챗봇 관련 논문들의 구현 ...
# 11  • (필수) 2년 이상의 해당 분야 개발 경험 또는 그에 준하는 역량 보유자• Py...
# 12  • ML 모델 개발 및 관련 경력 3년 이상인 분을 찾습니다.• 머신러닝 파이프라인...
# 13  • Python 기반 데이터 정제, 데이터 탐색, 피쳐 엔지니어링의 경험이 있으신 ...
# 14  • 하나 이상의 능숙한 프로그래밍 언어(Python, C++, Java) 및 She...
# 15  - 아래 조건 중 하나라도 해당하시는 분  A. LINER에 적재되는 텍스트, 비디...
# 16  - 서비스 프로그래밍 개발 역량이 있으신 분- Machine Learning 엔진 ...
# 17  • 머신러닝, 딥러닝 모델의 주요 개념들을 이해하고 계신 분• 머신러닝 논문들을 이...
# 18  • 다양한 머신러닝 알고리즘과 모델에 대한 깊은 흥미와 이해• 머신러닝을 활용해 실...
# 19  • 3년 이상의 머신러닝/Computer Vision 연구 혹은 개발 경력.• 딥러...
# 20  • 인공지능, 머신러닝, 딥러닝 개념을 이해하고 있으신 분• 머신러닝의 학습 종류를...
# 21  • Python, Go, Scala, Java, C++중 하나 이상의 언어에 능통하...
# 22  - 머신러닝, 딥러닝 등 인공지능 분야 경험- 협업툴 : Git GitHub, fi...
# 23  • Python 프로그래밍 실무 경력 (1년 이상)• 알고리듬 기반 솔루션 개발 유...
# 24                                                  0
# 25  • Python 프로그래밍 실무 경력 (1년 이상)• 딥러닝 지식 및 개발 경험• ...
# 26  [이런 역량을 갖춘 분을 찾습니다]- CS 전공 또는 CS학부 과정에 상응하는 커리...
# 27  • 컴퓨터공학, 머신러닝 관련 분야 석사 이상의 학위를 취득하신 분• 딥러닝 프레임...
# 28  • 컴퓨터공학, 머신러닝 관련 분야 석사 이상의 학위를 취득하신 분 또는 3년 이상...
# 29  • 데이터 분석 및 ML에 폭넓고 깊은 지식이 요구됩니다.• 하나 이상의 데이터 분...
# 30  • Python에 숙련된 프로그래밍 능력과 머신러닝 라이브러리 활용 경험• 머신러닝...
# 31  • Python에 숙련된 프로그래밍 능력과 머신러닝 라이브러리 활용 경험• 머신러닝...
# 32  • 학위 취득 후 최소 1년 이상 관련경험• 컴퓨터공학/통계학/수학/산업공학 관련 ...
# 33  • 컴퓨터과학, 전자공학, 데이터과학 및 관련 분야에서 석사 학위 혹은 3년 이상 ...
# 34  • 시계열예측/이상감지/최적화 등 머신러닝 프로젝트 수행경험이 있으신 분• 프레임워...
# 35  • 학사 학위 이상 학력 소지자로서 정보 과학 및 기계 학습 분야 1~3년 경력 보...
#
#                                                  우대사항  \
# 0   • 논문을 읽고 구현한 경험이 있으신 분• Docker, k8s 등의 Contain...
# 1   • ML 관련 Low Latency API 개발 경험이 있으신 분• 머신러닝 파이프...
# 2   - 상용 딥러닝 모델 구현 경험이 있으신 분- MLflow, WandB, Neptu...
# 3   - 인공지능 업계 경험- 머신러닝 관련 분야의 석/박사 학위 또는 그에 준하는 경험...
# 4   • 머신러닝 팀을 리딩해 본 경험이 있으신 분이면 좋아요.• 머신러닝 데이터/서비스...
# 5                              • 원할한 영어 구현 (말하기 및 쓰기)
# 6   • 이공계열 석사 이상• 머신러닝 top-tier conference • 의학 주요...
# 7   • 금융 관련 서비스 기획, 운영 경험이 있는 분• 웹 서비스 개발 기술 이해도가 ...
# 8   [이런 역량이 있으면 더욱 좋습니다]- 유관 조직에서 테크 리드 경험을 보유하신 분...
# 9   • 대용량 데이터 처리가 가능한 스케일러블한 머신러닝 시스템을 구축해본 경험이 있습...
# 10                                     •\t상용 챗봇 운영 경험
# 11                                                  0
# 12  • Docker 또는 Kubernetes 기반 환경의 서비스 구축 경험이 있으면 좋...
# 13  • EDA 경험이 있으신 분 • 데이터 관련 competition에 참가한 경험이 ...
# 14  • 추상적인 요구 사항으로부터 Task를 도출하실 수 있는 분• ML 프로젝트 리드...
# 15  - 클라우드 기반으로 모델 학습을 수행할 수 있는 분- 최신 딥러닝 관련 논문을 이...
# 16  - NLP ML 엔진 개발 및 서비스 적용 경험이 다수 있으신 분- IT 계열 로그...
# 17  • 머신러닝/추천시스템 관련 프로젝트를 경험하셨거나 추천 알고리즘에 대한 경험을 보...
# 18  • 수학, 통계, 엔지니어링 전공 MS or PH.D• 머신러닝, 인공지능, 데이터...
# 19  • 컴퓨터공학/통계학/수학 등 관련 분야 학위• Human Pose Estimati...
# 20  • AI 관련 스타트업 종사 경험이 있으신 분• Cloud platform (AWS...
# 21  • 실제 제품/서비스에 머신러닝 기술을 적용해본 경험• 머신러닝 모델 배포 파이프라...
# 22  ## 선호하는 인재상- 책임감있게 업무를 진행하시는 분- 끊임 없이 새로운 분야를 ...
# 23      • 딥러닝 지식 보유 • 수학 백그라운드가 강한 분 • 원활한 소통 및 협업 능력
# 24                                                  0
# 25  • 추천 엔진 개발 유경험자• Transformer 기반 딥러닝 개발 유경험자• 원...
# 26  [이런 역량이 있으면 더욱 좋습니다]- 문제해결을 즐기고, 새로운 기술을 배우는 것...
# 27  • 비정형 텍스트 데이터의 모델링 경험이 있으신 분• NLP 오픈소스의 활용 및 C...
# 28  • 음성합성용 음성 DB구축/가공 경험을 보유하신 분• E2E 음성합성 오픈소스의 ...
# 29  • 컴퓨터 공학, 데이터 마이닝, ML 관련 분야 학사 또는 석사 학위를 가지신 분...
# 30  • 현업 업무 및 서비스에 데이터분석/머신러닝 적용 경험• 통계 및 머신러닝 관련 ...
# 31  • 현업 업무 및 서비스에 데이터 분석/머신러닝 적용 경험• 통계 및 머신러닝 관련...
# 32  • NLP 관련 딥러닝 지식 및 활용 경험• NLP 관련 솔루션 설계 및 개발 경험...
# 33  • 5년 이상의 딥러닝 프로젝트 경험 혹은 컴퓨터과학, 전자공학, 데이터과학 및 관...
# 34  • Docker/kubernetes 기반 서비스 운영 경험• 워크플로우 관리 도구(...
# 35  • 컴퓨터 과학 석사학위 또는 박사학위 소지자• 프로젝트 관리 경험• 국가보훈대상자...
#
#                                               혜택 및 복지  \
# 0   근무환경• 단순히 직장을 다닌다는 느낌보다, 우리가 믿는 바를 실현하기 위해 함께 ...
# 1   근무환경• 단순히 직장을 다닌다는 느낌보다, 우리가 믿는 바를 실현하기 위해 함께 ...
# 2   [쾌적한 업무 환경]- 쾌적한 사무실, 편안한 자유 복장- 고사양 업무 디바이스 제...
# 3   • 생일휴가 - 연차 소진 없는 휴가 1일을 제공합니다.• 탄력 출퇴근 - 8시에서...
# 4   따뜻한 프로페셔널 ABLY, 당신을 위해 아낌없이 지원해요.[몰입할 수 있는 최고의...
# 5   • 입사 시 주식연계형 보상(RSU) 지급• 완전 자율출퇴근제• 연차 및 재택근무의...
# 6   • [개발직군] 주요 논문 출판 시, 500~2,000만원 보상금• 눈치보지 않고 ...
# 7   성장 지원• 외부 교육 지원 (인터넷 강의, 세미나 등)• 사내 스터디 지원• 도서...
# 8   [줌인터넷의 생활을 공개합니다]Work P+US : 업무에 온전히 몰입할 수 있도록...
# 9   • 기본적인 버즈빌리언의 생활을 위하여,- 점심식대 지원 및 무제한 간식/음료/고급...
# 10  •\t구성원의 개인 생활 및 영역에 대한 존중•\t개개인의 상황을 최대한 배려하여 ...
# 11  1. 간식비는 회사가 전적으로 책임집니다. • pushbar 운영 (음료와 간식 3...
# 12  • 업무에 필요한 최신 기기 및 환경 제공 (Macbook Pro)• 삼성역 근처 ...
# 13  • 자율과 효율성에 기반한 최적의 근무환경 • 잠실역 5분 거리 사무실 (롯데월드타...
# 14  ▶ 직원들의 성장을 지원합니다  • 외부 유료 교육 및 세미나 지원  • 사내 도서...
# 15  - 자율 출근 시간, 주 40시간 근무- 업계 최고 업무 장비 지원 (인당 500만...
# 16  • 개인 별 라이프 스타일에 따른 자율 출근 (8am~10am)• 최고의 접근성 (...
# 17  • 최신 업무장비를 제공 합니다.• 도서구입 및 자기개발비를 지원 합니다.• 매월 ...
# 18  아이지에이웍스는 오직 업무에만 집중할 수 있도록 다양한 복리후생 프로그램을 제공하고...
# 19  • 주도적인 업무환경 및 성장 기회• 주 5일 자율출퇴근/유연근무 (주 40시간 근...
# 20  • [데일리언이 되신 것을 환영합니다!] 슬리퍼, 텀블러, 후드 집업 등 슬기로운 ...
# 21  • 8시~11시 사이에 자율적으로 출근• 주 2~3회 재택근무 (개발조직 근무체계 ...
# 22         • 재택근무• 글로벌 팀 영어 소통 • 수평적 조직 문화 • 자기계발비 지원
# 23  • 하렉스인포텍의 연봉 제도는 기존의 연공서열 중심의 승진 및 호봉제도에 기반한 임...
# 24                                                  0
# 25  • 하렉스인포텍의 연봉 제도는 기존의 연공서열 중심의 승진 및 호봉제도에 기반한 임...
# 26  [이스트패밀리의 생활을 공개합니다]Work P+US : 업무에 온전히 몰입할 수 있...
# 27  • 사내 식당 (점심, 저녁 무료 제공)• 기념일 지원/행사 : 선물을 비롯한 현금...
# 28  • 사내 식당 (점심, 저녁 무료 제공)• 기념일 지원/행사 : 선물을 비롯한 현금...
# 29  더 많은 프로젝트와 일하는 방식 등이 궁금하시다면, 링크 (https://bit.l...
# 30  • Work & Life Balance 지원을 위한 마일리지/보육 시설/카페테리아/...
# 31  • Work & Life Balance 지원을 위한 마일리지/보육 시설/카페테리아/...
# 32  • 자유로운 분위기! 회식강요 안함 / 자유복장 / 자유로운 연차사용• 자녀 폴리 ...
# 33                            • 최고수준의 연봉• 유연한 유급 휴가 등
# 34  • 자율 출퇴근매일 매일 편한 시간에 출근하세요(9~10) 하루 8시간 열심히 근무...
# 35                                    • 4대 보험, 퇴직연금 등
#
#                                              기술스택 ・ 툴  \
# 0                                           ['Excel']
# 1                                           ['Excel']
# 2   ['Github', 'JIRA', 'Slack', 'MySQL', 'Pytorch'...
# 3   ['Confluence', 'GitLab', 'JIRA', 'Slack', 'Obj...
# 4   ['Github', 'Django', 'MySQL', 'Redis', 'JavaSc...
# 5                                                   0
# 6   ['Github', 'Pytorch', 'Tensorflow', 'Python', ...
# 7   ['Confluence', 'Git', 'Slack', 'Trello', 'Andr...
# 8   ['Git', 'Github', 'GitLab', 'Slack', 'Android'...
# 9                                ['Python', 'Golang']
# 10                                                  0
# 11  ['React', 'Java', 'Node.js', 'AWS', 'React.js'...
# 12  ['Git', 'JIRA', 'Django', 'MySQL', 'JavaScript...
# 13                                            ['PHP']
# 14                 ['Java', 'Eclipse', 'Spring Boot']
# 15  ['Git', 'MySQL', 'Pytorch', 'React', 'Tensorfl...
# 16                    ['TypeScript', 'AWS', 'NodeJS']
# 17                                                  0
# 18       ['Git', 'C#', 'Python', 'SQL', 'OOP', 'AWS']
# 19  ['Github', 'Android', 'iOS', 'React', 'JavaScr...
# 20  ['Github', 'MySQL', 'PHP', 'Python', 'AWS', 'P...
# 21                                                  0
# 22  ['Git', 'MySQL', 'React', 'Python', 'AWS', 'Sp...
# 23        ['Linux', 'Tensorflow', 'Python', 'Docker']
# 24                                                  0
# 25        ['Linux', 'Tensorflow', 'Python', 'Docker']
# 26  ['Git', 'Github', 'Android', 'AngularJS', 'iOS...
# 27                              ['Python', 'Tableau']
# 28                              ['Python', 'Tableau']
# 29                                                  0
# 30                   ['Java', 'AWS', 'Docker', 'GCP']
# 31                   ['Java', 'AWS', 'Docker', 'GCP']
# 32  ['ExtJS', 'VueJS', 'Java', 'JavaScript', 'Type...
# 33                                                  0
# 34              ['Java', 'Python', 'Go', 'OpenStack']
# 35     ['Git', 'Python', '컴퓨터 비전', '머신 비전', 'OpenCV']
#
#                                              지역
# 0             서울특별시 성동구 성수동1가 656-292 패스트파이브 9층
# 1             서울특별시 성동구 성수동1가 656-292 패스트파이브 9층
# 2                          서울 강남구 도곡로3길 27, 10층
# 3                 08788 서울시 관악구 남부순환로 1838, 11층
# 4                 서울특별시 서초구 강남대로 465, 교보타워 6,9층
# 5                         서울시 강남구 강남대로 636 두원빌딩
# 6                       서울 구로구 디지털로34길 43, 906호
# 7                    서울특별시 영등포구 국제금융로2길 17, 13층
# 8               서울특별시 서초구 서초3동 1464-30 이스트빌딩 7층
# 9                 서울특별시 송파구 석촌호수로 272 MY빌딩 2~5층
# 10                        서울시 중구 삼일대로 343 (위워크)
# 11                     서울특별시 여의나루로57 신송센터빌딩 13층
# 12          06168 서울 강남구 테헤란로 503 패스트파이브 삼성 3호점
# 13                     송파구 올림픽로 300, 롯데월드타워 디쉐어
# 14  경기 용인시 수지구 광교중앙로 338 광교 우미뉴브지식산업센터 A동 1011호
# 15                         서울특별시 마포구 홍익로 25, 3층
# 16                     강남구 테헤란로2길 27 비전타워 1401호
# 17                    서울특별시 강남구 테헤란로107길 6 두양빌딩
# 18                  서울시 마포구 양화로 45 세아타워 15층/20층
# 19                 서울특별시 서초구 서초대로 396, 강남빌딩 17층
# 20            서울시 강남구 언주로 620, 9층 (논현동, 현대인텔렉스)
# 21        서울특별시 용산구 서빙고로 17(한강로3가), 센트럴파크타워 10층
# 22              서울 중구 남대문로9길 24 패스트파이브 타워 3-12층
# 23                             서울특별시 중구 퇴계로 202
# 24                             서울특별시 중구 퇴계로 202
# 25                             서울특별시 중구 퇴계로 202
# 26          서울특별시 서초구 반포대로 3 이스트빌딩(서초동 1464-30)
# 27      서울특별시 강남구 논현로 72길 23, 2층 (역삼동770, 송하빌딩)
# 28      서울특별시 강남구 논현로 72길 23, 2층 (역삼동770, 송하빌딩)
# 29              서울특별시 영등포구 국제금융로8길 16 신영증권빌딩 9층
# 30                  경기도 성남시 분당구 판교로 256번길 7, 넥슨
# 31                  경기도 성남시 분당구 판교로 256번길 7, 넥슨
# 32                               서울특별시 송파구 송파대로
# 33                                          서초구
# 34            마포구 상암산로76 YTN 뉴스퀘어 16층 오케스트로 연구소
# 35                             경북 포항시 남구 청암로 77
