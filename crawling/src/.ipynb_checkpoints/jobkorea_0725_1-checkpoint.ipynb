# %%
# 막혔을때 예외처리
# 스킬 추가

# %%
# conda install beautifulsoup4
# conda install selenium
import time
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
#import requests
from selenium.webdriver.common.by import By
import pandas as pd
import random
import re
import numpy as np
import sys
import copy

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        ## Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--blink-setting=imagesEnabled=false') # 이미지 로딩 안함
#options.add_argument('--mute-audio') # 음소거
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--disable-site-isolation-trials")
#options.add_argument('--disable-setuid-sandbox')
options.add_argument('--incognito') # 시크릿모드
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
    AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36') # user와 같은 설정 주기
chromedriver = '../data/chromedriver'
try:
    driver.quit()
except NameError:
    pass
finally:
    driver = webdriver.Chrome(chromedriver, options=options) # 크롬 드라이버 설정

# %%
def remove_tags(string):
    return re.sub('<.+?>', '', str(string), 0).strip()

def save_1row(data):
    global Data
    length = Data.shape[0]
    Data.loc[length] = data
    return

def reset_Data():
    global Data
    Data = pd.DataFrame({}, columns=[\
        'title','job', 'cname','duties','skills', 'preference', 'welfare', 'loc',\
        'rec type','url', 'keyword'])
    return

def get_job_keyword(job):
    global ijob, ikeyword
    job_list = ['데이터 엔지니어', '데이터 분석가', '데이터 사이언티스트', '머신러닝 엔지니어', \
                '데이터 플랫폼 개발자', 'DBA', '임베디드', 'IoT', '마켓팅 데이터', '정보보안', \
                '백엔드', '풀스택']
    job_keywords = {'데이터 엔지니어':['데이터 엔지니어'], \
                    '데이터 분석가': ['데이터 분석가'], \
                    '데이터 사이언티스트': ['데이터 사이언티스트'],\
                    '머신러닝 엔지니어': ['머신러닝 엔지니어', 'ML'], \
                    '데이터 플랫폼 개발자':['데이터 플랫폼 개발자'], \
                    'DBA' : ['DBA', '데이터베이스 관리자'], \
                    '임베디드':['임베디드'],\
                    'IoT':['IoT'],\
                    '마켓팅 데이터':['마켓팅 데이터'],\
                    '정보보안':['정보보안'],\
                    '백엔드':['백엔드', 'backend'],\
                    '풀스택':['풀스택', 'fullstack']}
    if job is '':
        ijob = 0
        ikeyword = 0
    elif ikeyword+1 == len(job_keywords[job]):
        ijob += 1
        ikeyword = 0
    else:
        ikeyword += 1
    if ijob == len(job_list):
        return ('None')                     ################# None 반환시 끝내기 
    job = job_list[ijob];
    keyword = job_keywords[job][ikeyword]
    return (job, keyword)

def get_job_html(base_url, job, keyword):
    driver.get(base_url)
    search_job = driver.find_element('xpath', '//*[@id="stext"]')
    search_job.send_keys(keyword+Keys.ENTER)
    time.sleep(3+3*random.random()) # 랜덤으로
    html = driver.page_source
    html_jobs = BeautifulSoup(html, 'html.parser')
    return (html_jobs)

def get_recruit_html(base_url, recruit):
    rec_url = recruit['href']
    search_url = base_url + rec_url
    driver.get(search_url)
    stime = 1+2*random.random()
    time.sleep(stime)
    html_recruit = BeautifulSoup(driver.page_source, 'html.parser')
    return (html_recruit, search_url)

def get_iframe_html(base_url, iframe):
    driver.switch_to.frame('gib_frame') # iframe으로 옮겨가기
    stime = 1+1*random.random()
    time.sleep(stime)
    html_iframe = BeautifulSoup(driver.page_source, 'html.parser')
    return (html_iframe)

def get_next_job_html(base_url, page_url):
    driver.get(base_url + page_url)
    stime = 3+2*random.random()
    html = driver.page_source
    html_jobs = BeautifulSoup(html, 'html.parser')
    return (html_jobs)

# %%
job = ''; keyword = ''
site = 'https://www.jobkorea.co.kr/'
reset_Data()

# %%
job, keyword = get_job_keyword(job)

html_jobs_1page = get_job_html(site, job, keyword)

# %%
pages = html_jobs_1page.find_all('div', {'class':'tplPagination newVer wide'})[1].select('li')
max_pages = len(pages)
print (f'\n\njob {job}')
print (f'keyword {keyword}')
print (f'ijob, ikeyword {ijob}, {ikeyword}')
print (f'max page {max_pages}')

max_pages = min(max_pages, 5)
ipage = 0
irec = 0
while ipage < max_pages:
    if ipage > 0:
        html_jobs = get_next_job_html(site, pages[ipage].select('a')[0]['href'])
    else:
        html_jobs = copy.copy(html_jobs_1page)
    recruit_default = html_jobs.find('div', {'class':'list-default'})
    recruit_items = recruit_default.find_all('li', {'class':'list-post'}) # list-post / list-post active

    print (f'\npage {ipage} / {max_pages}')
    print ('total ',len(recruit_items))
    while irec/20 < ipage+1 and irec%20 < len(recruit_items):
        
        ii = irec%20
        print (f'\nstart {irec}')

        recruit = recruit_items[ii].find('a', {'class':'dev_view'})
        if str(type(recruit)) == "<class 'NoneType'>": 
            irec += 1
            continue
        html_recruit, url = get_recruit_html(site, recruit)
        iframe = html_recruit.find('iframe', {'title':'상세요강'}) # html 내의 document (iframe) 처리
        html_iframe = get_iframe_html(site, iframe)

        # title, job, company, url
        title = remove_tags(html_recruit.find('title'))
        company = remove_tags(html_recruit.find('span', {'class':'coName'}))
        html_str = str(html_iframe)

        # keywords and location
        keywords = ''
        loc = ''
        assoc_keywords = html_recruit.find('article', {'id':'artKeywordSearch'})
        if str(assoc_keywords) != 'None':
            for key in assoc_keywords.find_all('li'):
                if str(key).find('btnLocal') > -1:
                    loc += remove_tags(key).replace('&gt;', '>')
                    continue
                keywords += remove_tags(key) + ', '

        # rec type
        rec = ''
        apply_qual = remove_tags(html_recruit.find('dl', {'class':'tbList'})).replace('\n','')
        apply_qual1 = apply_qual.find('경력')
        apply_qual2 = apply_qual.find('학력')
        if apply_qual2 >= 0:
            rec = apply_qual[apply_qual1+2:apply_qual2].replace(' ','')
        else:
            rec = apply_qual[apply_qual1+2:].replace(' ','')

        # 상세 채용 정보 내용
        duties = ''
        skills = ''
        preference = ''
        welfare = ''

        content = html_iframe.find('div', {'class':'detailed-summary-contents'})
        img = html_iframe.find('div', {'class':'detailReadImg'})
        if str(content) != 'None':
            ps = content.find_all('p')
            for ip in ps:
                str_ip = remove_tags(ip)
                if '담당업무' in str(ip): # duties
                    case = 1
                elif any([needs in str(ip) for needs in ['필수', '자격']]): # skills
                    case = 2
                elif '우대' in str(ip): # preference
                    case = 3
                elif any([i in str(ip) for i in ['복지', '복리']]): # welfare
                    case = 4
                elif any([i in str(ip) for i in ['전형절차']]):
                    case = -1
                try:
                    if case == 1: # duties
                        duties += str_ip + '\n'
                    elif case == 2: # skills
                        skills += str_ip + '\n'
                    elif case == 3: # preference
                        preference += str_ip + '\n'
                    elif case == 4: # welfare
                        welfare += str_ip + '\n'
                    elif case == -1: # others
                        print ('other : ',str_ip)
                except NameError:
                    pass
        elif str(img) != 'None':
            pass

        # Data에 저장
        data = [title, job, company, duties, skills, preference, welfare, loc, rec, url, keywords]
        save_1row(data)
        
        irec += 1
        
    ipage += 1
print ('finished')
# Out:
# job 풀스택
# keyword fullstack
# ijob, ikeyword 11, 1
# max page 3
#
# page 0 / 3
# total  20
#
# start 0
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 최종합격
# other :
# other :  접수방법
# other :  ㆍ접수방법 : 홈페이지 지원, 전화 지원
# other :  ㆍ이력서양식 : 자유양식
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 1
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ1차 대면 면접 전 코딩테스트를 보내드립니다.
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 2
#
# start 3
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접  &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 4
#
# start 5
#
# start 6
#
# start 7
#
# start 8
#
# start 9
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :  Applicants can submit CV - Both Email - Sunil.Chandran@quest-global.com;Kihwan.Seol@quest-global.com
#
# start 10
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  근무조건
# other :  ㆍ근무형태 : 정규직(수습기간 3개월)
# other :  ㆍ근무부서 : 사이트팀
# other :  ㆍ근무요일/시간 : 주 5일(월~금) 오전 9시 ~오후 6시
# other :  ㆍ근무지(구로 오피스) : 서울 구로구 구로동 188-25, 구로지밸리비즈플라자 14층
# other :  ㆍ급여 : 면접 후 결정
# other :
# other :  접수방법 및 기간
# other :  ㆍ제출서류 : 잡코리아 이력서 및 자기소개서
# other :  ㆍ접수방법 : 잡코리아 온라인 지원
# other :  ㆍ접수기간 : 채용시 마감
# other :
# other :  기타사항
# other :  ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.
#
# start 11
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  근무조건
# other :  ㆍ근무형태 : 정규직(수습기간 3개월)
# other :  ㆍ근무부서 : 클라우드팀
# other :  ㆍ근무요일/시간 : 주 5일(월~금) 오전 9시 ~ 오후 6시
# other :  ㆍ근무지(구로 오피스) : 서울 구로구 구로동 188-25, 구로지밸리비즈플라자 14층
# other :  ㆍ급여 : 면접 후 결정
# other :
# other :  접수방법 및 기간
# other :  ㆍ접수방법 : 잡코리아 온라인 지원(잡코리아 이력서 및 자기소개서)
# other :  ㆍ접수기간 : 채용시 마감
# other :  ㆍ문의 : hhkim@iparking.co.kr
# other :
# other :
# other :  기타사항
# other :  ㆍ입사지원 서류에 허위사실이 발견될 경우, 채용확정 이후라도 채용이 취소될 수 있습니다.
#
# start 12
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 13
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 14
# other :  전형절차
# other :  ㆍ서류전형 &gt; 면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 15
# other :  전형절차
# other :  ㆍ서류전형 &gt; 코딩테스트 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  근무환경
# other :  ㆍ급여 :경력 및 근무 조건에 따라 협의, 업계 최고 수준
#
# start 16
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 17
# other :  전형절차
# other :  ㆍ서류전형 &gt; 코딩테스트 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  근무환경
# other :  ㆍ급여 :경력 및 근무 조건에 따라 협의, 업계 최고 수준
#
# start 18
# other :  전형절차
# other :  ㆍ서류전형 &gt; 면접(간단한 코딩 테스트) &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  접수기간 및 방법
# other :  ㆍ채용시까지
# other :  ㆍ잡코리아 온라인 입사지원
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 19
# other :  전형절차
# other :  ㆍ서류전형 &gt; 면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# page 1 / 3
# total  20
#
# start 20
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 21
#
# start 22
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
#
# start 23
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
# other :  &lt;마곡 사옥&gt;
# other :
# other :  &lt;압구정 사옥&gt;
# other :
#
# start 24
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
#
# start 25
#
# start 26
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
#
# start 27
#
# start 28
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
#
# start 29
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 기술과제 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :
# other :
#
# start 30
#
# start 31
#
# start 32
#
# start 33
# other :  [채용 포지션]
# other :  - 사업운영본부 사업전략실 Fullstack Developer
# other :
# other :  [주요업무]
# other :  ? 컴퓨터 공학 지식: CS 전공자 혹은 그와 준하는 지식
# other :  ? React 프레임워크 개발 경험을 가지신 분
# other :  ? Spring Framework, JSP, RESTful API 기반 개발 경험
# other :  ? SQL이나 NoSQL 기반의 개발 경험
# other :
#
# start 34
#
# start 35
# other :  전형절차
# other :  ㆍ서류전형 &gt; 면접 ( 임원면접 ) &gt; 최종합격
# other :  ㆍ면접은 상황에 따라 1차 또는 2차 진행
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# other :  [ 지원방법 ] 이력서
# other :  이진성 전무 ( 010-2419-1592 , jslee@naslekorea.com
# other :
# other :  - ASAP로 진행되므로 관심 있는 분들의 빠른 지원 바랍니다.
# other :  ( 문의사항은 메일이나 연락 부탁 드립니다 )
# other :
#
# start 36
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 37
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 38
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 39
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# page 2 / 3
# total  4
#
# start 40
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 41
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 42
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
#
# start 43
# finished

# %%
import openpyxl
Data.to_excel('../output/DataScience_0725_15.xlsx')

# %%
print (url)
Data.tail(5)
# Out:
# https://www.jobkorea.co.kr//Recruit/GI_Read/38193815?PageGbn=HH&logpath=1&stext=fullstack&listno=44
#                                                   title  job cname  \
# 1412  벤처기업 : 모바일 기반 기업 클라우드 &amp; 백오피스 개발자 5년이상 | 잡코...  풀스택  None
# 1413  벤처기업 : 스마트 통합 솔루션 모바일 기반 기업 클라우드 &amp; 백오피스 개발...  풀스택  None
# 1414                      중견기업 : 자바 백엔드 개발자 | 잡코리아 헤드헌팅  풀스택  None
# 1415  대기업 계열사·자회사 : 자바 백엔드 5년-10년 경력 개발자 채용 | 잡코리아 헤드헌팅  풀스택  None
# 1416      중소기업 : 강남구 강남역 AI기업 full-stack개발자 | 잡코리아 헤드헌팅  풀스택  None
#
#                              duties  \
# 1412
# 1413
# 1414
# 1415  담당업무\nㆍ웹 어플리케이션 개발 및 운영\n\n\n
# 1416
#
#                                                  skills  \
# 1412                      모집분야 및 자격요건\n모집분야명 ( 0명 )\n\n
# 1413                      모집분야 및 자격요건\n모집분야명 ( 1명 )\n\n
# 1414  모집분야 및 자격요건\n자바 백엔드 개발( ○명 )\n- 정산시스템 개발- 즉시 감...
# 1415  모집분야 및 자격요건\n모집분야명 ( 3명 )\n자격요건\nㆍ학력 : 학력무관\nㆍ...
# 1416
#
#                                              preference welfare loc rec type  \
# 1412                                                                     one
# 1413                                                                     one
# 1414                                                                     one
# 1415  우대사항\nㆍRest API 개발 가능자\nㆍRDBMS, NoSQL 개발 가능자\n...                  one
# 1416                                                                     one
#
#                                                     url keyword
# 1412  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 1413  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 1414  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 1415  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 1416  https://www.jobkorea.co.kr//Recruit/GI_Read/38...

# %%
Data = pd.read_excel('../output/DataScience_0725_3.xlsx', index_col=0)
Data
# Out:
#                                                  title         job  \
# 0           비즈테크아이 채용 - [LG그룹] BI/DW데이터 엔지니어 채용 | 잡코리아    데이터 엔지니어
# 1            웅진씽크빅 채용 - [웅진씽크빅] 정규직 데이터 엔지니어 채용 | 잡코리아    데이터 엔지니어
# 2              텐바이텐 채용 - [텐바이텐] 데이터 엔지니어 경력직 채용 | 잡코리아    데이터 엔지니어
# 3                        네이버제트 채용 - 데이터 엔지니어 모집 | 잡코리아    데이터 엔지니어
# 4    삼성웰스토리 채용 - B2B 온라인(E커머스) 및 Data 부문 경력사원 채용 (데...    데이터 엔지니어
# ..                                                 ...         ...
# 258  GfK리테일앤테크놀로지코리아리미티드 채용 - [GfK]  Market Insight...  데이터 사이언티스트
# 259         오아시스비즈니스 채용 - [오아시스비즈니스] UI/UX 디자이너 | 잡코리아  데이터 사이언티스트
# 260              파두 채용 - 주식회사 파두 부문별 신입/경력 채용공고 | 잡코리아  데이터 사이언티스트
# 261               오에스씨코리아 채용 - 오픈소스 기반 전부문 인재채용 | 잡코리아  데이터 사이언티스트
# 262             오픈소스잡 채용 - 2022년 IT교육플랫폼 실무인재양성 | 잡코리아  데이터 사이언티스트
#
#                     cname                                             duties  \
# 0                 ㈜비즈테크아이                                                NaN
# 1                  ㈜웅진씽크빅                                                NaN
# 2                   ㈜텐바이텐                                                NaN
# 3                   네이버제트  담당업무\nㆍ제페토의 핵심 데이터 수집, 활용 정책 수립\nㆍ제페토의 정형 비정형 ...
# 4                 삼성웰스토리㈜  담당업무\nㆍ데이터 품질 관리\n- 핵심 Data 수집 정책 수립, DB 품질 관리...
# ..                    ...                                                ...
# 258  GfK리테일앤테크놀로지코리아리미티드㈜                                                NaN
# 259             ㈜오아시스비즈니스                                                NaN
# 260                    파두                                                NaN
# 261               오에스씨코리아                                                NaN
# 262                ㈜오픈소스잡                                                NaN
#
#                                                 skills  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    모집분야 및 자격요건\n데이터 엔지니어\n자격요건\nㆍ관련 분야 개발 경력 3년 이...
# 4    모집분야 및 자격요건\n데이터 엔지니어\n자격요건\nㆍ데이터 가공 및 분산 처리 기...
# ..                                                 ...
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
#
#                                             preference welfare  \
# 0                                                  NaN     NaN
# 1                                                  NaN     NaN
# 2                                                  NaN     NaN
# 3    우대사항\nㆍ대용량 / 실시간 데이터 처리 아키텍쳐 구축 경험이 있는 분\nㆍ클라우...     NaN
# 4    우대사항\nㆍ컴퓨터공학, AI, SW, 산업공학 등 관련 전공\nㆍAWS SageM...     NaN
# ..                                                 ...     ...
# 258                                                NaN     NaN
# 259                                                NaN     NaN
# 260                                                NaN     NaN
# 261                                                NaN     NaN
# 262                                                NaN     NaN
#
#                                      loc     rec type  \
# 0                               서울 > 마포구           경력
# 1                                서울 > 중구     경력(3년이상)
# 2                               서울 > 종로구     경력(1년이상)
# 3                           경기 > 성남시 분당구           경력
# 4                           경기 > 성남시 분당구           경력
# ..                                   ...          ...
# 258                             서울 > 용산구     경력(2년이상)
# 259                             서울 > 강남구         경력무관
# 260                             서울 > 강남구        신입·경력
# 261                     서울 > 강남구서울 > 서초구  신입·경력(1년이상)
# 262  서울 > 강남구서울 > 중구서울 > 서울전지역경기 > 경기전지역        신입·경력
#
#                                                    url  \
# 0    https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 1    https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 2    https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 3    https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 4    https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# ..                                                 ...
# 258  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 259  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 260  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 261  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 262  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
#
#                                                keyword
# 0    IT분야 직무채용관, QA·테스터·검증, Windows, 리눅스, DBA·데이터베이...
# 1    IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DBA, DW, SQL, ...
# 2    IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 웹프로그래머, Py...
# 3    IT분야 직무채용관, IT·솔루션·기술영업, 웹사이트구축영업, 네트워크·서버·보안,...
# 4    IT분야 직무채용관, 외식 직무채용관, 빅데이터·AI(인공지능), Python, 데...
# ..                                                 ...
# 258          외국계기업 전문채용관, 마케팅·광고·분석, 시장분석, 컨설팅·연구·조사,
# 259  성동구X성수 스타트업 채용관, 웹디자인, GUI, UI·UX디자인, 웹UI, 모바일...
# 260  반도체·디스플레이, 연구원, 전기·전자, 제품개발, 회로설계, 연구관리, 반도체·디...
# 261  우수벤처기업 공동채용관, IT분야 직무채용관, IT·솔루션·기술영업, 기술영업, 기...
# 262  IT분야 직무채용관, 웹프로그래머, Java, jsp, SQL, Servlet, A...
#
# [263 rows x 11 columns]
