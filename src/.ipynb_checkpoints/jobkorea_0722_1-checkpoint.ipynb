# %%
# 막혔을때 예외처리
# 스킬 추가

# %%
# conda install beautifulsoup4
# conda install selenium
import time
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
#import requests
from selenium.webdriver.common.by import By
import pandas as pd
import random
import re
import numpy as np
import sys
import copy

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')        ## Head-less 설정
options.add_argument('--no-sandbox')
options.add_argumetn('--blink-setting=imagesEnabled=false') # 이미지 로딩 안함
#options.add_argument('--mute-audio') # 음소거
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--disable-site-isolation-trials")
#options.add_argument('--disable-setuid-sandbox')
options.add_argument('--incognito') # 시크릿모드
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
    AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36') # user와 같은 설정 주기
chromedriver = '../data/chromedriver'
try:
    driver.quit()
except NameError:
    pass
finally:
    driver = webdriver.Chrome(chromedriver, options=options) # 크롬 드라이버 설정

# %%
def remove_tags(string):
    return re.sub('<.+?>', '', str(string), 0).strip()

def save_1row(data):
    global Data
    length = Data.shape[0]
    Data.loc[length] = data
    return

def reset_Data():
    global Data
    Data = pd.DataFrame({}, columns=[\
        'title','job', 'cname','duties','skills', 'preference', 'welfare', 'loc',\
        'rec type','url', 'keyword'])
    return

def get_jobs_html(base_url, job):
    global ijob, ikeyword
    job_list = ['데이터 엔지니어', '데이터 분석가', '데이터 사이언티스트', '머신러닝 엔지니어', \
                '데이터 플랫폼 개발자', 'DBA', '임베디드', 'IoT', '마켓팅 데이터', '정보보안', \
                '백엔드', '풀스택']
    job_keywords = {'데이터 엔지니어':['데이터 엔지니어'], \
                    '데이터 분석가': ['데이터 분석가'], \
                    '데이터 사이언티스트': ['데이터 사이언티스트'],\
                    '머신러닝 엔지니어': ['머신러닝 엔지니어', 'ML'], \
                    '데이터 플랫폼 개발자':['데이터 플랫폼 개발자'], \
                    'DBA' : ['DBA', '데이터베이스 관리자'], \
                    '임베디드':['임베디드'],\
                    'IoT':['IoT'],\
                    '마켓팅 데이터':['마켓팅 데이터'],\
                    '정보보안':['정보보안'],\
                    '백엔드':['백엔드', 'backend'],\
                    '풀스택':['풀스택', 'fullstack']}
    if job is '':
        ijob = 0
        ikeyword = 0
    elif ikeyword+1 == len(job_keywords[job]):
        ijob += 1
        ikeyword = 0
    else:
        ikeyword += 1
    if ijob == len(job_list):
        return ('None')
    job = job_list[ijob];
    keyword = job_keywords[job][ikeyword]
    
    driver.get(base_url)
    search_job = driver.find_element('xpath', '//*[@id="stext"]')
    search_job.send_keys(keyword+Keys.ENTER)
    time.sleep(3+3*random.random()) # 랜덤으로
    html = driver.page_source
    html_jobs = BeautifulSoup(html, 'html.parser')
    return (html_jobs, job)

def get_recruit_html(base_url, recruit):
    rec_url = recruit['href']
    search_url = base_url + rec_url
    driver.get(search_url)
    stime = 1+2*random.random()
    time.sleep(stime)
    html_recruit = BeautifulSoup(driver.page_source, 'html.parser')
    return (html_recruit, search_url)

def get_iframe_html(base_url, iframe):
    driver.switch_to.frame('gib_frame') # iframe으로 옮겨가기
    stime = 1+1*random.random()
    time.sleep(stime)
    html_iframe = BeautifulSoup(driver.page_source, 'html.parser')
    return (html_iframe)

# %%
job = ''
site = 'https://www.jobkorea.co.kr/'
reset_Data()

# %%
html_jobs, job = get_jobs_html(site, job)
recruit_default = html_jobs.find('div', {'class':'list-default'})
recruit_items = recruit_default.find_all('li', {'class':'list-post'}) # list-post / list-post active

# %%
####### 각 채용공고당 진행
# for-loop start

print ('total ',len(recruit_items))
for ii in range(len(recruit_items)):
    print ('start ',ii)
    recruit = recruit_items[ii].find('a', {'class':'title dev_view'})
    if str(type(recruit)) == "<class 'NoneType'>": continue
    html_recruit, url = get_recruit_html(site, recruit)
    iframe = html_recruit.find('iframe', {'title':'상세요강'}) # html 내의 document (iframe) 처리
    html_iframe = get_iframe_html(site, iframe)

    # title, job, company, url
    title = remove_tags(html_recruit.find('title'))
    company = remove_tags(html_recruit.find('span', {'class':'coName'}))
    html_str = str(html_iframe)

    # keywords and location
    keyword = ''
    loc = ''
    assoc_keyword = html_recruit.find('article', {'id':'artKeywordSearch'})
    for key in assoc_keyword.find_all('li'):
        if str(key).find('btnLocal') > -1:
            loc += remove_tags(key).replace('&gt;', '>')
            continue
        keyword += remove_tags(key) + ', '

    # rec type
    rec = ''
    apply_qual = remove_tags(html_recruit.find('dl', {'class':'tbList'})).replace('\n','')
    apply_qual1 = apply_qual.find('경력')
    apply_qual2 = apply_qual.find('학력')
    if apply_qual2 >= 0:
        rec = apply_qual[apply_qual1+2:apply_qual2].replace(' ','')
    else:
        rec = apply_qual[apply_qual1+2:].replace(' ','')

    # 상세 채용 정보 내용
    duties = ''
    skills = ''
    preference = ''
    welfare = ''
    
    content = html_iframe.find('div', {'class':'detailed-summary-contents'})
    img = html_iframe.find('div', {'class':'detailReadImg'})
    if str(content) != 'None':
        ps = content.find_all('p')
        for ip in ps:
            # duties
            str_ip = remove_tags(ip)
            if '담당업무' in str(ip): # duties
                case = 1
            elif any([needs in str(ip) for needs in ['필수', '자격']]): # skills
                case = 2
            elif '우대' in str(ip): # preference
                case = 3
            elif any([i in str(ip) for i in ['복지', '복리']]): # welfare
                case = 4
            elif any([i in str(ip) for i in ['전형절차']]):
                case = -1
            try:
                if case == 1: # duties
                    duties += str_ip + '\n'
                elif case == 2: # skills
                    skills += str_ip + '\n'
                elif case == 3: # preference
                    preference += str_ip + '\n'
                elif case == 4: # welfare
                    welfare += str_ip + '\n'
                elif case == -1: # others
                    print ('other : ',str_ip)
            except NameError:
                pass
    elif str(img) != 'None':
        pass

    # Data에 저장
    data = [title, job, company, duties, skills, preference, welfare, loc, rec, url, keyword]
    save_1row(data)
# Out:
# total  20
# start  0
# start  1
# start  2
# start  3
# other :  전형절차
# other :  ㆍ서류전형  &gt;  1차 면접  &gt;  인성검사 &amp; 2차 면접  &gt;  채용 건강검진  &gt;  입사
# other :  ㆍ전형 절차는 일정 및 상황에 따라 변동 될 수 있습니다.
# other :  ㆍ진행 일정은 확정되는 대로 지원자분들에게 개별 안내 예정입니다.
# other :
# other :  안내사항
# other :  ㆍ지원서 내용 중 허위 사실이 있는 경우에는 합격이 취소될 수 있습니다.
# other :  ㆍ본 전형 지원 완료 시 사용한 이메일로 지원서 제출 확인 메일이 발송되고 있으며, 서류 합격 여부는 결과와 상관없이
# other :  개인별 안내해 드리고 있습니다.
# start  4
# other :  전형절차
# other :  ㆍ서류전형 → 면접전형 → 건강검진 → 최종합격 (8월 중 예정)
# other :
# other :  근무형태
# other :  ㆍ정규직
# other :
# other :  접수방법
# other :  ㆍ2022.07.20(수) ~ 2022.08.01(월) 23시 55분까지 당사 채용 홈페이지를 통한 온라인 접수
# other :  - 첨부된 경력기술서 작성 후 [Essay] 화면 내 '이력서 첨부' 란에 첨부 (파일명 : '성명' 으로 제출)
# start  5
# other :  전형절차
# other :  ㆍ서류전형 &gt; 인적성검사 &gt; 1차면접 &gt; 2차면접 &gt; 건강검진 &gt; 최종전형
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 07. 14 ~ 2022. 07. 31 23:00
# other :  ㆍ접수방법 : LG그룹 채용 사이트(LG Careers)를 통한 온라인 입사지원서 제출만 가능
# other :  ㆍ문의처 : LG Careers 로그인 후 [1:1질문하기] 이용
# other :
# other :  기타사항
# other :  ㆍ당사는 영업정보, 기술정보, 경영정보, 업무상 비밀 등 기타의 경제적 가치가 있는 모든 정보를 정당한 정보원으로부터 적법하게
# other :  수집하며, 타인의 정보를 입수, 이용, 공유할 때는 적법하고 올바른 절차를 준수합니다. 또한 타인의 아이디어, 저작물, 기타 지적
# other :  산물은 권리자가 라이선스 권을 부여해준 경우 등 당사가 사용할 수 있는 법적 권한을 가지고 있는 경우에만 한정하여 사용합니다.     특히 당사는 타사의 영업비밀을 부정한 방법으로 취득, 사용하지 않습니다.
# other :  이상과 같은 공정경쟁 원칙에 따라 당사는 채용 예정자로부터 前 회사 소유의 어떠한 자료도 요구하거나 전달 받지 않습니다.
# other :  따라서 귀하는 업무 능력 증명 등의 목적으로 당사에 前 회사의 영업비밀 관련 자료를 전달해서는 안되며, 前 회사 영업비밀을
# other :  임의로 전달할 경우에는 채용상 불이익이 있을 수 있습니다.
# other :  ㆍ자세한 상세요강은 반드시 채용 홈페이지에서 직접 확인해 주시기 바랍니다.
# start  6
# other :  전형절차
# other :  ㆍ서류전형 → 코딩테스트전형 → 1차 실무진 면접전형 → 2차 경영진 면접전형 → 연봉 및 처우협의 → 최종합격
# other :  ㆍ각 전형 결과 및 면접 일정은 홈페이지 및 메일을 통해 개별적으로 안내 드리고 있습니다.
# other :  ㆍ서류전형 결과 발표일 : 2022년 8월 16일 화요일 이내
# other :  ㆍ입사지원서 제출일의 익월 중순까지 서류전형 결과를 안내 드리고 있습니다.
# other :  ㆍ공고에 게시된 서류전형 결과 발표일보다 전형결과 안내가 늦어질 경우 개별적으로 연락 드릴 예정입니다.
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 07. 11(월) ~ 2022. 07. 31(일) 23:59
# other :  ㆍ접수방법 : 당사 채용 홈페이지 온라인 지원
# other :  ㆍ모집기간 : 영입 완료시 마감
# other :  ㆍ영입 완료 시 조기에 마감될 수 있는 수시채용으로 진행 중입니다.
# other :  ㆍ영입이 완료될 경우 해당월 말일로 설정된 공고마감일이 도래하지 않더라도 일찍 마감될 수 있습니다.
# other :  ㆍ영입이 완료되기 전까지 매월 1일 새롭게 공고가 업로드됩니다. (*전월 공고에 제출한 입사지원서는 정상적으로 검토 진행)
# other :
# other :  기타사항
# other :  ㆍ입사지원서에 기재된 내용은 증빙자료 제출을 통해 확인하고 있습니다.
# other :  기재된 내용이 사실과 다를 경우 입사가 취소될 수 있음을 유의하여 주시길 바랍니다.
# other :  ㆍ부정한 채용청탁을 한 사실이 밝혀질 경우 입사가 취소될 수 있음을 유의하여 주시길 바랍니다.
# other :  ㆍ카카오뱅크 내규에 따라 채용 금지자에 해당하는 분은 입사가 어려움을 유의하여 주시길 바랍니다.
# other :  ㆍ자세한 상세요강은 반드시 채용 홈페이지에서 직접 확인해 주시기 바랍니다.
# start  7
# start  8
# start  9
# start  10
# other :  전형절차
# other :  ㆍ서류전형 &gt; 면접진행 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# start  11
# other :  전형절차
# other :  ㆍ서류전형 &gt; 인적성검사 &gt; 1차면접 &gt; 2차면접 &gt; 건강검진 &gt; 최종전형
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 05. 17 ~ 2022. 12. 31 23:00
# other :  ㆍ접수방법 : 반드시 LG그룹 채용사이트(careers.lg.com)을 통한 온라인 지원만 가능
# other :  ㆍ우편접수, e-mail 접수 및 방문접수 불가
# other :  ㆍ문의처 : LG Careers - 채용문의 - 1:1질문하기
# other :
# other :  기타사항
# other :  ㆍ인적성검사 중 인성검사만 실시하며, 서류전형 통과자에 한하여 실시함. 일정 및 방법은 대상자 개별 안내 예정입니다.
# other :  ㆍ필요 시 면접을 추가로 진행할 수 있습니다.
# other :  ㆍ개인별 경력 및 면접 결과에 따라 개별 처우 협의하며 고용형태는 정규직 또는 전문계약직이 될 수 있습니다.
# other :  ㆍ입사지원서는 모든 사항을 정확하게 입력해야 하며, 추후 입력사항이 허위로 판명될 경우에는 입사(합격)가 취소됩니다.
# other :  ㆍ지원직무 및 근무지는 지원자의 선택을 최우선 고려하여 배치하나, 업무적합도 및 분야별 채용규모에 따라 다른 지원분야에서
# other :  면접이 진행 될 수 있으며 추가 면접 전형이 진행될 수 있습니다.
# start  12
# other :  전형절차
# other :  ㆍ서류전형 &gt; 인적성검사 &gt; 1차면접 &gt; 2차면접 &gt; 건강검진 &gt; 최종전형
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 05. 17 ~ 2022. 12. 31 23:00
# other :  ㆍ접수방법 : 반드시 LG그룹 채용사이트(careers.lg.com)을 통한 온라인 지원만 가능
# other :  ㆍ우편접수, e-mail 접수 및 방문접수 불가
# other :  ㆍ문의처 : LG Careers - 채용문의 - 1:1질문하기
# other :
# other :  기타사항
# other :  ㆍ인적성검사 중 인성검사만 실시하며, 서류전형 통과자에 한하여 실시함. 일정 및 방법은 대상자 개별 안내 예정입니다.
# other :  ㆍ필요 시 면접을 추가로 진행할 수 있습니다.
# other :  ㆍ개인별 경력 및 면접 결과에 따라 개별 처우 협의하며 고용형태는 정규직 또는 전문계약직이 될 수 있습니다.
# other :  ㆍ입사지원서는 모든 사항을 정확하게 입력해야 하며, 추후 입력사항이 허위로 판명될 경우에는 입사(합격)가 취소됩니다.
# other :  ㆍ지원직무 및 근무지는 지원자의 선택을 최우선 고려하여 배치하나, 업무적합도 및 분야별 채용규모에 따라 다른 지원분야에서
# other :  면접이 진행 될 수 있으며 추가 면접 전형이 진행될 수 있습니다.
# start  13
# other :  전형절차
# other :  ㆍ서류전형 &gt; 인적성검사 &gt; 1차면접 &gt; 2차면접 &gt; 건강검진 &gt; 최종전형
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 05. 17 ~ 2022. 12. 31 23:00
# other :  ㆍ접수방법 : 반드시 LG그룹 채용사이트(careers.lg.com)을 통한 온라인 지원만 가능
# other :  ㆍ우편접수, e-mail 접수 및 방문접수 불가
# other :  ㆍ문의처 : LG Careers - 채용문의 - 1:1질문하기
# other :
# other :  기타사항
# other :  ㆍ인적성검사 중 인성검사만 실시하며, 서류전형 통과자에 한하여 실시함. 일정 및 방법은 대상자 개별 안내 예정입니다.
# other :  ㆍ필요 시 면접을 추가로 진행할 수 있습니다.
# other :  ㆍ개인별 경력 및 면접 결과에 따라 개별 처우 협의하며 고용형태는 정규직 또는 전문계약직이 될 수 있습니다.
# other :  ㆍ입사지원서는 모든 사항을 정확하게 입력해야 하며, 추후 입력사항이 허위로 판명될 경우에는 입사(합격)가 취소됩니다.
# other :  ㆍ지원직무 및 근무지는 지원자의 선택을 최우선 고려하여 배치하나, 업무적합도 및 분야별 채용규모에 따라 다른 지원분야에서
# other :  면접이 진행 될 수 있으며 추가 면접 전형이 진행될 수 있습니다.
# start  14
# other :  전형절차
# other :  ㆍ서류전형 &gt; 인적성검사 &gt; 1차면접 &gt; 2차면접 &gt; 건강검진 &gt; 최종전형
# other :
# other :  접수기간 및 방법
# other :  ㆍ접수기간 : 2022. 05. 17 ~ 2022. 12. 31 23:00
# other :  ㆍ접수방법 : 반드시 LG그룹 채용사이트(careers.lg.com)을 통한 온라인 지원만 가능
# other :  ㆍ우편접수, e-mail 접수 및 방문접수 불가
# other :  ㆍ문의처 : LG Careers - 채용문의 - 1:1질문하기
# other :
# other :  기타사항
# other :  ㆍ인적성검사 중 인성검사만 실시하며, 서류전형 통과자에 한하여 실시함. 일정 및 방법은 대상자 개별 안내 예정입니다.
# other :  ㆍ필요 시 면접을 추가로 진행할 수 있습니다.
# other :  ㆍ개인별 경력 및 면접 결과에 따라 개별 처우 협의하며 고용형태는 정규직 또는 전문계약직이 될 수 있습니다.
# other :  ㆍ입사지원서는 모든 사항을 정확하게 입력해야 하며, 추후 입력사항이 허위로 판명될 경우에는 입사(합격)가 취소됩니다.
# other :  ㆍ지원직무 및 근무지는 지원자의 선택을 최우선 고려하여 배치하나, 업무적합도 및 분야별 채용규모에 따라 다른 지원분야에서
# other :  면접이 진행 될 수 있으며 추가 면접 전형이 진행될 수 있습니다.
# start  15
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt; 임원면접 &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# start  16
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; 2차면접 &gt;최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# start  17
# start  18
# other :  전형절차
# other :  ㆍ서류전형 &gt; 1차면접 &gt; (임원면접 → 필요시 진행) &gt; 최종합격
# other :  ㆍ면접일정은 추후 통보됩니다.
# other :
# other :  유의사항
# other :  ㆍ허위사실이 발견될 경우 채용이 취소될 수 있습니다.
# other :
# start  19

# %%
import openpyxl
Data.to_excel('../output/DataScience_0722_1.xlsx')

# %%
print (url)
Data
# Out:
# https://www.jobkorea.co.kr//Recruit/GI_Read/38222493?Oem_Code=C1&logpath=1&stext=데이터 엔지니어&listno=20
#                                                 title job           cname  \
# 0          비즈테크아이 채용 - [LG그룹] BI/DW데이터 엔지니어 채용 | 잡코리아             ㈜비즈테크아이
# 1          비즈테크아이 채용 - [LG그룹] BI/DW데이터 엔지니어 채용 | 잡코리아             ㈜비즈테크아이
# 2           웅진씽크빅 채용 - [웅진씽크빅] 정규직 데이터 엔지니어 채용 | 잡코리아              ㈜웅진씽크빅
# 3             텐바이텐 채용 - [텐바이텐] 데이터 엔지니어 경력직 채용 | 잡코리아               ㈜텐바이텐
# 4                       네이버제트 채용 - 데이터 엔지니어 모집 | 잡코리아               네이버제트
# 5   삼성웰스토리 채용 - B2B 온라인(E커머스) 및 Data 부문 경력사원 채용 (데...             삼성웰스토리㈜
# 6   엘지전자 채용 - [글로벌마케팅센터] 데이터 사이언스 분야 경력채용 (데이터 엔지니...               엘지전자㈜
# 7                 카카오뱅크 채용 - [빅데이터분석] 데이터 엔지니어 | 잡코리아               카카오뱅크
# 8   휴머스온 채용 - [데이터엔지니어] [데이터사이언티스트] [데이터 분석가] 경력 모...           주식회사 휴머스온
# 9               위메이드 채용 - 데이터 엔지니어 담당자 ( 주니어 ) | 잡코리아                위메이드
# 10                       위메이드 채용 - 데이터 엔지니어 팀장 | 잡코리아                위메이드
# 11  마이셀럽스 채용 - [마이셀럽스] 데이터 엔지니어(Junior) 경력직 채용 | 잡코리아            (주)마이셀럽스
# 12  엘지전자 채용 - [CDO부문] 데이터 엔지니어/클라우드 엔지니어/데이터 플랫폼 개...               엘지전자㈜
# 13  엘지전자 채용 - [CDO부문] 데이터 엔지니어/클라우드 엔지니어/데이터 플랫폼 개...               엘지전자㈜
# 14  엘지전자 채용 - [CDO부문] 데이터 엔지니어/클라우드 엔지니어/데이터 플랫폼 개...               엘지전자㈜
# 15  엘지전자 채용 - [CDO부문] 데이터 엔지니어/클라우드 엔지니어/데이터 플랫폼 개...               엘지전자㈜
# 16               하나투어 채용 - 하나투어 DW 데이터 엔지니어 채용 | 잡코리아               ㈜하나투어
# 17          유클릭 채용 - SQL튜너,데이터 엔지니어, DBA 모십니다. | 잡코리아                ㈜유클릭
# 18  위메이드 채용 - 플랫폼 개발자 / DBA / 데이터 엔지니어 / 웹 UI 개발 |...               ㈜위메이드
# 19  케이디엑스한국데이터거래소 채용 - 데이터 분석 / 데이터 엔지니어 분야 정규직(경력...      ㈜케이디엑스한국데이터거래소
# 20                      지니 채용 - 데이터엔지니어 개발자 모집 | 잡코리아                 ㈜지니
#
#                                                duties  \
# 0
# 1
# 2
# 3
# 4   담당업무\nㆍ제페토의 핵심 데이터 수집, 활용 정책 수립\nㆍ제페토의 정형 비정형 ...
# 5   담당업무\nㆍ데이터 품질 관리\n- 핵심 Data 수집 정책 수립, DB 품질 관리...
# 6   담당업무\nㆍ마케팅 분석 업무를 위한 데이터 마트 설계 / 개발 및 운영\nㆍ내부 ...
# 7   담당업무\nㆍ분석엔지니어링\n- 데이터 기반의 분석을 위한 데이터 마트 개발 및 운...
# 8
# 9
# 10
# 11  담당업무\nㆍ데이터 파이프라인 구축 운영\nㆍ다양한 외부 데이터 수집\nㆍETL 프...
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19  담당업무\nㆍ빅데이터 SW개발 및 통계 알고리즘 개발 분석ㆍ빅데이터 솔루션 데이터 ...
# 20
#
#                                                skills  \
# 0
# 1
# 2
# 3
# 4   모집분야 및 자격요건\n데이터 엔지니어\n자격요건\nㆍ관련 분야 개발 경력 3년 이...
# 5   모집분야 및 자격요건\n데이터 엔지니어\n자격요건\nㆍ데이터 가공 및 분산 처리 기...
# 6   모집분야 및 자격요건\n데이터 엔지니어( 0명 )\nㆍ필수 조건\n- GCP(Goo...
# 7   모집분야 및 자격요건\n데이터 엔지니어( 0명 )\n필수 경험과 역량\nㆍSQL, ...
# 8
# 9
# 10
# 11  모집분야 및 자격요건\n\n\n\n\n\n\n\n데이터 엔지니어(Junior)\n\...
# 12  모집분야 및 자격요건\nData 플랫폼 개발\n입사 후 역할\nㆍ전사 데이터 환경을...
# 13  모집분야 및 자격요건\nCloud Engineer\n입사 후 역할\nㆍ효과적인 전사...
# 14  모집분야 및 자격요건\nData Engineer\n입사 후 역할\nㆍLG전자 Dat...
# 15  모집분야 및 자격요건\nData Engineer\n입사 후 역할\nㆍLG전자 Dat...
# 16  모집분야 및 자격요건\n\n\n\n\n\nDW 데이터 엔지니어 ( ○명 )\n자격요...
# 17  모집분야 및 자격요건\n모집분야명 ( o명 )\n● 자격사항\n\n- 관련학과 전공...
# 18
# 19  모집분야 및 자격요건\n데이터 분석 / 데이터 엔지니어 분야(경력)( ○명 )\n자...
# 20
#
#                                            preference  \
# 0
# 1
# 2
# 3
# 4   우대사항\nㆍ대용량 / 실시간 데이터 처리 아키텍쳐 구축 경험이 있는 분\nㆍ클라우...
# 5   우대사항\nㆍ컴퓨터공학, AI, SW, 산업공학 등 관련 전공\nㆍAWS SageM...
# 6                       우대사항\nㆍ7년 이상의 빅데이터 엔지니어링 경력\n
# 7   우대사항\nㆍHadoop EcoSystem 기반의 플랫폼 환경에서 데이터 파이프라인...
# 8
# 9
# 10
# 11  우대사항\nㆍ확장성 및 신뢰성 중심의 아키텍쳐를 설계 가능\nㆍAWS(ECS, EC...
# 12  ㆍ우대사항\n- Data Architecture, 알고리즘, 분산 서비스 개발 경험...
# 13  ㆍ우대사항\n- Container, Kubernetes 그리고 Serverless ...
# 14  ㆍ우대사항\n- Data 플랫폼 기획/구축/운영/성능 개선 경험\n- Ad-hoc,...
# 15  ㆍ우대사항\n1) Data Engineer\n- Data 플랫폼 기획/구축/운영/성...
# 16  우대사항\nㆍOLAP Solution(MSTR) 운영 및 개발 유경험자\nㆍCDC ...
# 17
# 18
# 19  우대사항\nㆍ통계, 빅데이터, 머신러닝, 딥러닝 관련 전공 및 학위를 보유하고 있거...
# 20
#
#                                               welfare                     loc  \
# 0                                                                    서울 > 마포구
# 1                                                                    서울 > 마포구
# 2                                                                     서울 > 중구
# 3                                                                    서울 > 종로구
# 4                                                                경기 > 성남시 분당구
# 5                                                                경기 > 성남시 분당구
# 6                                                                   서울 > 영등포구
# 7                                                                경기 > 성남시 분당구
# 8                                                          서울 > 강남구서울 > 서울전지역
# 9                                                                경기 > 성남시 분당구
# 10                                                               경기 > 성남시 분당구
# 11  복리후생\nㆍ연차 상관 없는 높은 연봉 상승율, 스톡옵션\nㆍ수평적인 문화 제도 (...                서울 > 강남구
# 12                                                                  서울 > 영등포구
# 13                                                                  서울 > 영등포구
# 14                                                                  서울 > 영등포구
# 15                                                                  서울 > 영등포구
# 16                                                                    서울 > 중구
# 17                                                                    서울 > 중구
# 18                                                               경기 > 성남시 분당구
# 19                                                                    서울 > 중구
# 20                                                     경기 > 성남시 분당구경기 > 경기전지역
#
#     rec type                                                url  \
# 0         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 1         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 2   경력(3년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 3   경력(1년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 4         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 5         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 6         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 7         경력  https://www.jobkorea.co.kr//Recruit/GI_Read/39...
# 8   경력(2년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 9       경력무관  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 10  경력(5년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 11  경력(2년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 12        경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 13        경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 14        경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 15        경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 16  경력(3년이상)  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 17     신입·경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 18     신입·경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 19        경력  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
# 20      경력무관  https://www.jobkorea.co.kr//Recruit/GI_Read/38...
#
#                                               keyword
# 0   IT분야 직무채용관, QA·테스터·검증, Windows, 리눅스, DBA·데이터베이...
# 1   IT분야 직무채용관, QA·테스터·검증, Windows, 리눅스, DBA·데이터베이...
# 2   IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DBA, DW, SQL, ...
# 3   IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 웹프로그래머, Py...
# 4   IT분야 직무채용관, IT·솔루션·기술영업, 웹사이트구축영업, 네트워크·서버·보안,...
# 5   IT분야 직무채용관, 외식 직무채용관, 빅데이터·AI(인공지능), Python, 데...
# 6   IT분야 직무채용관, 빅데이터·AI(인공지능), 데이터분석, 빅데이터, 하둡(Had...
# 7   금융·영업 직무채용관, IT분야 직무채용관, DBA·데이터베이스, SQL, 데이터베...
# 8   이달의 우수 중소기업 일자리, 강소기업 채용관, IT분야 직무채용관, 빅데이터·AI...
# 9   IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 빅데이터·AI(인공...
# 10  IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 빅데이터·AI(인공...
# 11  IT분야 직무채용관, 빅데이터·AI(인공지능), 빅데이터, 데이터분석, 포털·컨텐츠...
# 12  IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 시스템프로그래머, ...
# 13  IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 시스템프로그래머, ...
# 14  IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 응용프로그래머, L...
# 15  IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DW, 웹프로그래머, Ja...
# 16  일학습병행 채용관, IT분야 직무채용관, 빅데이터·AI(인공지능), 데이터분석, 빅...
# 17  강소기업 채용관, IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, SQL,...
# 18  히든챔피언 채용관, IT분야 직무채용관, DBA·데이터베이스, 데이터베이스, DBA...
# 19  IT분야 직무채용관, DBA·데이터베이스, SQL, 빅데이터·AI(인공지능), 데이...
# 20  이달의 우수 중소기업 일자리, IT분야 직무채용관, DBA·데이터베이스, MySQL...
